# %%
#
#jobcardprefetchquery
string='urn%3Ali%3Afsd_jobPostingCard%3A%283605835026%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283677607748%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283248391847%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283702328989%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283705267885%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283624475314%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283684253710%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283714812282%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283719366796%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283704110887%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283705287579%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283719131081%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283691766063%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283691540316%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283691239727%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283709347991%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283705277986%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283721055251%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283662545243%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283711146367%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283698080926%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283709343753%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283684556536%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283714195544%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283715489136%2CJOB_DETAILS%29'
for i in string.split(','):
    print(i.split('%2C')[0].split('%3A')[-1][3:])
# Out:
# 3605835026
# 3677607748
# 3248391847
# 3702328989
# 3705267885
# 3624475314
# 3684253710
# 3714812282
# 3719366796
# 3704110887
# 3705287579
# 3719131081
# 3691766063
# 3691540316
# 3691239727
# 3709347991
# 3705277986
# 3721055251
# 3662545243
# 3711146367
# 3698080926
# 3709343753
# 3684556536
# 3714195544
# 3715489136

# %%
import requests
query='urn%3Ali%3Afsd_jobPostingCard%3A%283693308691%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283704201568%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283624475314%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283248391847%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283707310354%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283719366796%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283705699066%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283694915230%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283715635585%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283697105288%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283714812282%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283605835026%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283700249898%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283607455656%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283699961159%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283561149188%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283707376438%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283708165269%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283705988224%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283676476387%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283681885093%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283696302209%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283700298587%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283665727865%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283714438268%2CJOB_DETAILS%29'

url = f"https://www.linkedin.com/voyager/api/graphql?includeWebMetadata=true&variables=(jobCardPrefetchQuery:(jobUseCase:JOB_DETAILS,prefetchJobPostingCardUrns:List({query})))&&queryId=voyagerJobsDashJobCards.020b4482c526b8d851e1be8cb6abd1ae"

headers = {
    "authority": "www.linkedin.com",
    "accept": "application/vnd.linkedin.normalized+json+2.1",
    "accept-language": "tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7",
    "cookie": "li_sugr=2bea2606-963c-4987-b2c3-bfb2ca7cd20e; bcookie=v=2&34acc383-8567-4bfd-80f7-d2318a762e3c; bscookie=v=1&202307091228218e0d528b-c2b4-493a-80dc-61cf3ae2fe30AQG96bPRTNcKkrs_fVWAeBYBTYoc8aTg; _gcl_au=1.1.1266958154.1688908501; g_state={i_l:0}; liap=true; JSESSIONID=ajax:5303730033043348444; li_theme=light; li_theme_set=app; timezone=Europe/Istanbul; aam_uuid=02217823255985045961787499542289630624; s_fid=242CDA6E3F186D2E-2950028D500AF295; s_ips=931; gpv_pn=developer.linkedin.com%2Fproduct-catalog; s_tp=4997; s_tslv=1692771112195; mbox=session#c693feaa7f6441bc95d0bf6e067751ba#1692772973|PC#c693feaa7f6441bc95d0bf6e067751ba.37_0#1708323113; UserMatchHistory=AQIaxLtEf_sZwQAAAYqssioOxNXrjU7Na75Bjrk-ivFQ6SuBh-R-TbWdglyQOz5UHp4udR6OV1mKBA; AnalyticsSyncHistory=AQJgMboanbvmMAAAAYqssioOjfxZqEsQ41fgQ06qf4V3TtZ14ZEp4YWXO1uUyfvT4QQAD0xgEQk00LKzPl4RvA; lms_ads=AQG1SAvauO9FCwAAAYqssitbEKH6xrrJvbsjFmURvdRf-sD6SwXqk64at9DtnOjeexKAETXY5XbPB9VI_zQi_oBF6BTyeO7F; lms_analytics=AQG1SAvauO9FCwAAAYqssitbEKH6xrrJvbsjFmURvdRf-sD6SwXqk64at9DtnOjeexKAETXY5XbPB9VI_zQi_oBF6BTyeO7F; li_at=AQEDATII6h8AeTsrAAABikrJIiIAAAGK0L6vKk0AZcHEqAE9WelD8jEtZZyZe3XQzeJNgUxCAZ-5h9-EsVQ5v5hgPzJ4oXMIxcCHKZLrr_RaoQf8fRPL7Or6WLJA-xlagrE2AZVomvToMbEKOe2RwzuR; lang=v=2&lang=tr-tr; AMCVS_14215E3D5995C57C0A495C55@AdobeOrg=1; AMCV_14215E3D5995C57C0A495C55@AdobeOrg=-637568504|MCIDTS|19620|MCMID|02783115663670449591729758703456499307|MCAAMLH-1695767803|6|MCAAMB-1695767803|6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y|MCOPTOUT-1695170203s|NONE|vVersion|5.1.1|MCCIDH|86075867; __cf_bm=DU.ibjS8LHHL7eH8qhGKe3ITejQTN87hlX25P8NtpAQ-1695163673-0-AfVLtV4QEAKjCqJUOIrxvwBykzJ2kcoSCEXIe6PRRvEabfaUwAQM4btyIsqnrRESSbe+PG8sd5NWVHv87gSR8B4=; sdsc=22^3A1^2C1695164234960^7EJAPP^2C0f4^2BsoAZxjT1iLun6fLCBmWa5u7E^3D; lidc=b=TB23:s=T:r=T:a=T:p=T:g=5141:u=61:x=1:i=1695164235:t=1695164859:v=2:sig=AQGlEN-hXhmJfHmiJLOuYIfxWxmTHAwh",
    "csrf-token" : "ajax:5303730033043348444",
"referer" : "https://www.linkedin.com/jobs/search/?currentJobId=3605835026&keywords=front%20end&origin=BLENDED_SEARCH_RESULT_CARD_NAVIGATION",
"sec-ch-ua" : "Chromium;v=116, Not)A;Brand;v=24, Google Chrome;v=116",
"sec-ch-ua-mobile" : "?0",
"sec-ch-ua-platform" : "Windows",
"sec-fetch-dest" : "empty",
"sec-fetch-mode" : "cors",
"sec-fetch-site" : "same-origin",
"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36",
"x-li-lang" : "tr_TR",
"x-li-page-instance" : "urn:li:page:d_flagship3_search_srp_jobs;WzN9yXy7SnShgeyR7HsP0w==",
"x-li-prefetch" : "1",
"x-li-track" : '{"clientVersion":"1.13.3561","mpVersion":"1.13.3561","osName":"web","timezoneOffset":3,"timezone":"Europe/Istanbul","deviceFormFactor":"DESKTOP","mpName":"voyager-web","displayDensity":1,"displayWidth":1920,"displayHeight":1080}',
"x-restli-protocol-version" : "2.0.0",
    
}




response = requests.get(url, headers=headers)
abc=response.json()

# %%
general_dict={}
for listing in abc["included"]:
    new_listing = {}
    if "descriptionText" in listing.keys():
        zipd=listing["entityUrn"].split(":")[-1]
        #new_listing["companyName"] = listing["title"]
        new_listing["postedOnText"] = listing["postedOnText"]

        new_listing["description"] = listing["descriptionText"]["text"]
        general_dict.update({zipd:new_listing})
print(general_dict)
# Out:
# {'3248391847': {'postedOnText': '6 Eyl 2022 tarihinde yayınlandı.', 'description': 'ABOUT Jotform\nJotform is a San Francisco-based SaaS company with more than 20 million users worldwide. We are thriving and growing, and we’ve never needed outside funding. That’s because we like keeping things agile, independent and fun. Jotform believes everyone should be able to create their own online forms. Our 10,000+ ready-made form templates, 100+ integrations and more than 380 widgets have made us one of the most popular online form builders for organizations of all sizes — from small businesses to enterprises.\nSince our inception in 2006, our mission has been to help users create, manage and share online forms and receive responses in the easiest way possible.\nABOUT THE ROLE\nJotform is seeking a UI Developer in our Ankara office, located at a relaxed fun environment in Hacettepe University Teknokent. As a rapidly growing company we are hiring for similar positions continuously and once an
# ...

# %%
"""curl "https://www.linkedin.com/voyager/api/voyagerJobsDashJobCards?decorationId=com.linkedin.voyager.dash.deco.jobs.search.JobSearchCardsCollection-185&count=25&q=jobSearch&query=(origin:BLENDED_SEARCH_RESULT_CARD_NAVIGATION,keywords:front^%^20end,spellCorrectionEnabled:true)&start=0" ^
  -H "authority: www.linkedin.com" ^
  -H "accept: application/vnd.linkedin.normalized+json+2.1" ^
  -H "accept-language: tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7" ^
  -H "cookie: li_sugr=2bea2606-963c-4987-b2c3-bfb2ca7cd20e; bcookie=^\^"v=2&34acc383-8567-4bfd-80f7-d2318a762e3c^\^"; bscookie=^\^"v=1&202307091228218e0d528b-c2b4-493a-80dc-61cf3ae2fe30AQG96bPRTNcKkrs_fVWAeBYBTYoc8aTg^\^"; _gcl_au=1.1.1266958154.1688908501; g_state=^{^\^"i_l^\^":0^}; liap=true; JSESSIONID=^\^"ajax:5303730033043348444^\^"; li_theme=light; li_theme_set=app; timezone=Europe/Istanbul; aam_uuid=02217823255985045961787499542289630624; s_fid=242CDA6E3F186D2E-2950028D500AF295; s_ips=931; gpv_pn=developer.linkedin.com^%^2Fproduct-catalog; s_tp=4997; s_tslv=1692771112195; mbox=session^#c693feaa7f6441bc95d0bf6e067751ba^#1692772973^|PC^#c693feaa7f6441bc95d0bf6e067751ba.37_0^#1708323113; UserMatchHistory=AQIaxLtEf_sZwQAAAYqssioOxNXrjU7Na75Bjrk-ivFQ6SuBh-R-TbWdglyQOz5UHp4udR6OV1mKBA; AnalyticsSyncHistory=AQJgMboanbvmMAAAAYqssioOjfxZqEsQ41fgQ06qf4V3TtZ14ZEp4YWXO1uUyfvT4QQAD0xgEQk00LKzPl4RvA; lms_ads=AQG1SAvauO9FCwAAAYqssitbEKH6xrrJvbsjFmURvdRf-sD6SwXqk64at9DtnOjeexKAETXY5XbPB9VI_zQi_oBF6BTyeO7F; lms_analytics=AQG1SAvauO9FCwAAAYqssitbEKH6xrrJvbsjFmURvdRf-sD6SwXqk64at9DtnOjeexKAETXY5XbPB9VI_zQi_oBF6BTyeO7F; li_at=AQEDATII6h8AeTsrAAABikrJIiIAAAGK0L6vKk0AZcHEqAE9WelD8jEtZZyZe3XQzeJNgUxCAZ-5h9-EsVQ5v5hgPzJ4oXMIxcCHKZLrr_RaoQf8fRPL7Or6WLJA-xlagrE2AZVomvToMbEKOe2RwzuR; lang=v=2&lang=tr-tr; AMCVS_14215E3D5995C57C0A495C55^%^40AdobeOrg=1; AMCV_14215E3D5995C57C0A495C55^%^40AdobeOrg=-637568504^%^7CMCIDTS^%^7C19620^%^7CMCMID^%^7C02783115663670449591729758703456499307^%^7CMCAAMLH-1695767803^%^7C6^%^7CMCAAMB-1695767803^%^7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y^%^7CMCOPTOUT-1695170203s^%^7CNONE^%^7CvVersion^%^7C5.1.1^%^7CMCCIDH^%^7C86075867; __cf_bm=DU.ibjS8LHHL7eH8qhGKe3ITejQTN87hlX25P8NtpAQ-1695163673-0-AfVLtV4QEAKjCqJUOIrxvwBykzJ2kcoSCEXIe6PRRvEabfaUwAQM4btyIsqnrRESSbe+PG8sd5NWVHv87gSR8B4=; sdsc=22^%^3A1^%^2C1695164234960^%^7EJAPP^%^2C0f4^%^2BsoAZxjT1iLun6fLCBmWa5u7E^%^3D; lidc=^\^"b=TB23:s=T:r=T:a=T:p=T:g=5141:u=61:x=1:i=1695164235:t=1695164859:v=2:sig=AQGlEN-hXhmJfHmiJLOuYIfxWxmTHAwh^\^"" ^
  -H "csrf-token: ajax:5303730033043348444" ^
  -H "referer: https://www.linkedin.com/jobs/search/?currentJobId=3633373341&keywords=front^%^20end&origin=BLENDED_SEARCH_RESULT_CARD_NAVIGATION" ^
  -H "sec-ch-ua: ^\^"Chromium^\^";v=^\^"116^\^", ^\^"Not)A;Brand^\^";v=^\^"24^\^", ^\^"Google Chrome^\^";v=^\^"116^\^"" ^
  -H "sec-ch-ua-mobile: ?0" ^
  -H "sec-ch-ua-platform: ^\^"Windows^\^"" ^
  -H "sec-fetch-dest: empty" ^
  -H "sec-fetch-mode: cors" ^
  -H "sec-fetch-site: same-origin" ^
  -H "user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36" ^
  -H "x-li-lang: tr_TR" ^
  -H "x-li-page-instance: urn:li:page:d_flagship3_search_srp_jobs;WzN9yXy7SnShgeyR7HsP0w==" ^
  -H "x-li-pem-metadata: Voyager - Careers=jobs-search-results" ^
  -H "x-li-track: ^{^\^"clientVersion^\^":^\^"1.13.3561^\^",^\^"mpVersion^\^":^\^"1.13.3561^\^",^\^"osName^\^":^\^"web^\^",^\^"timezoneOffset^\^":3,^\^"timezone^\^":^\^"Europe/Istanbul^\^",^\^"deviceFormFactor^\^":^\^"DESKTOP^\^",^\^"mpName^\^":^\^"voyager-web^\^",^\^"displayDensity^\^":1,^\^"displayWidth^\^":1920,^\^"displayHeight^\^":1080^}" ^
  -H "x-restli-protocol-version: 2.0.0" ^
  --compressed"""

# %%
def find_word_path(obj, target_word, current_path=[]):
    if isinstance(obj, dict):
        for key, value in obj.items():
            new_path = current_path + [key]
            result = find_word_path(value, target_word, new_path)
            if result:
                return result
    elif isinstance(obj, list):
        for index, item in enumerate(obj):
            new_path = current_path + [index]
            result = find_word_path(item, target_word, new_path)
            if result:
                return result
    elif obj == target_word:
        return current_path
print(find_word_path(abc,"SEO Executive"))
# Out:
# ['included', 40, 'title']

# %%
for listing in abc["included"]:
    if "jobPostingTitle" in listing.keys():
        zipd=listing["preDashNormalizedJobPostingUrn"].split(":")[-1]
        print(listing["primaryDescription"]["text"])
        print(listing["jobPostingTitle"],"\n")
        general_dict[zipd]["jobPostingTitle"]=listing["jobPostingTitle"]
        general_dict[zipd]["primaryDescription"]=listing["primaryDescription"]["text"]
        
general_dict["3605835026"]
# Out:
# Odine · İstanbul, Türkiye · Yeniden yayınlandı 6 ay önce
# DevOps Engineer
#
# Turing · Türkiye · 10 ay önce
# Front-End Developer
#
# ANSR · İstanbul, Türkiye · Yeniden yayınlandı 6 ay önce
# Fullstack Engineer - React & Node (Abu Dhabi)
#
# Huawei · İstanbul, Türkiye · Yeniden yayınlandı 4 ay önce
# Front End Supervisor (Istanbul-Izmir-Ankara)
#
# GroupM · İstanbul, Türkiye · Yeniden yayınlandı 5 ay önce
# SEO Executive
#
# Commencis · İstanbul, Türkiye · Yeniden yayınlandı 6 ay önce
# UI Developer
#
# Sigorta Bilgi ve Gözetim Merkezi · Türkiye · 6 ay önce
# DevOps Engineer
#
# OBSS · Ankara, Türkiye · 6 ay önce
# Front End Developer
#
# SST Technology · Gebze, Kocaeli, Türkiye · 6 ay önce
# Senior Frontend Developer
#
# İşNet · İstanbul, Türkiye · Yeniden yayınlandı 5 ay önce
# RPA Developer
#
# Turkcell · İstanbul, Türkiye · 6 ay önce
# DEVOPS ENGINEER
#
# Novartis · İstanbul, İstanbul, Türkiye · Yeniden yayınlandı 5 ay önce
# ...

# %%
import requests

url = "https://www.linkedin.com/voyager/api/voyagerJobsDashJobCards?decorationId=com.linkedin.voyager.dash.deco.jobs.search.JobSearchCardsCollection-185&count=25&q=jobSearch&query=(origin:BLENDED_SEARCH_RESULT_CARD_NAVIGATION,keywords:front%20end,spellCorrectionEnabled:true)&start=0"

headers = {
    "authority": "www.linkedin.com",
    "accept": "application/vnd.linkedin.normalized+json+2.1",
    "accept-language": "tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7",
    "cookie": "li_sugr=2bea2606-963c-4987-b2c3-bfb2ca7cd20e; bcookie=v=2&34acc383-8567-4bfd-80f7-d2318a762e3c; bscookie=v=1&202307091228218e0d528b-c2b4-493a-80dc-61cf3ae2fe30AQG96bPRTNcKkrs_fVWAeBYBTYoc8aTg; _gcl_au=1.1.1266958154.1688908501; g_state={i_l:0}; liap=true; JSESSIONID=ajax:5303730033043348444; li_theme=light; li_theme_set=app; timezone=Europe/Istanbul; aam_uuid=02217823255985045961787499542289630624; s_fid=242CDA6E3F186D2E-2950028D500AF295; s_ips=931; gpv_pn=developer.linkedin.com%2Fproduct-catalog; s_tp=4997; s_tslv=1692771112195; mbox=session#c693feaa7f6441bc95d0bf6e067751ba#1692772973|PC#c693feaa7f6441bc95d0bf6e067751ba.37_0#1708323113; UserMatchHistory=AQIaxLtEf_sZwQAAAYqssioOxNXrjU7Na75Bjrk-ivFQ6SuBh-R-TbWdglyQOz5UHp4udR6OV1mKBA; AnalyticsSyncHistory=AQJgMboanbvmMAAAAYqssioOjfxZqEsQ41fgQ06qf4V3TtZ14ZEp4YWXO1uUyfvT4QQAD0xgEQk00LKzPl4RvA; lms_ads=AQG1SAvauO9FCwAAAYqssitbEKH6xrrJvbsjFmURvdRf-sD6SwXqk64at9DtnOjeexKAETXY5XbPB9VI_zQi_oBF6BTyeO7F; lms_analytics=AQG1SAvauO9FCwAAAYqssitbEKH6xrrJvbsjFmURvdRf-sD6SwXqk64at9DtnOjeexKAETXY5XbPB9VI_zQi_oBF6BTyeO7F; li_at=AQEDATII6h8AeTsrAAABikrJIiIAAAGK0L6vKk0AZcHEqAE9WelD8jEtZZyZe3XQzeJNgUxCAZ-5h9-EsVQ5v5hgPzJ4oXMIxcCHKZLrr_RaoQf8fRPL7Or6WLJA-xlagrE2AZVomvToMbEKOe2RwzuR; lang=v=2&lang=tr-tr; AMCVS_14215E3D5995C57C0A495C55^@AdobeOrg=1; AMCV_14215E3D5995C57C0A495C55^@AdobeOrg=-637568504|^7CMCIDTS|^7C19620|^7CMCMID|^7C02783115663670449591729758703456499307|^7CMCAAMLH-1695767803|^7C6|^7CMCAAMB-1695767803|^7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y|^7CMCOPTOUT-1695170203s|^7CNONE|^7CvVersion|^7C5.1.1|^7CMCCIDH|^7C86075867; __cf_bm=DU.ibjS8LHHL7eH8qhGKe3ITejQTN87hlX25P8NtpAQ-1695163673-0-AfVLtV4QEAKjCqJUOIrxvwBykzJ2kcoSCEXIe6PRRvEabfaUwAQM4btyIsqnrRESSbe+PG8sd5NWVHv87gSR8B4=; sdsc=22^3A1^2C1695164234960^7EJAPP^2C0f4^2BsoAZxjT1iLun6fLCBmWa5u7E^3D; lidc=^b=TB23:s=T:r=T:a=T:p=T:g=5141:u=61:x=1:i=1695164235:t=1695164859:v=2:sig=AQGlEN-hXhmJfHmiJLOuYIfxWxmTHAwh^",
    "csrf-token": "ajax:5303730033043348444",
    "referer": "https://www.linkedin.com/jobs/search/?currentJobId=3633373341&keywords=front%20end&origin=BLENDED_SEARCH_RESULT_CARD_NAVIGATION",
    "sec-ch-ua": 'Chromium;v=116, Not)A;Brand";v="24", "Google Chrome";v="116"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36",
    "x-li-lang": "tr_TR",
    "x-li-page-instance": "urn:li:page:d_flagship3_search_srp_jobs;WzN9yXy7SnShgeyR7HsP0w==",
    "x-li-pem-metadata": "Voyager - Careers=jobs-search-results",
    "x-li-track": '{"clientVersion":"1.13.3561","mpVersion":"1.13.3561","osName":"web","timezoneOffset":3,"timezone":"Europe/Istanbul","deviceFormFactor":"DESKTOP","mpName":"voyager-web","displayDensity":1,"displayWidth":1920,"displayHeight":1080}',
    "x-restli-protocol-version": "2.0.0"
}

response = requests.get(url, headers=headers)

# Check the response status code and handle it as needed
if response.status_code == 200:
    data = response.json()
    print("200")

    # Process the JSON data here
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# 200

# %%
#print(data["data"]["metadata"]["jobCardPrefetchQueries"][0]["prefetchJobPostingCard"])
str1='urn^%3Ali^%3Afsd_jobPostingCard^%3A%283605835026%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283707310354%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283700298587%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283715635585%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283681885093%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283696302209%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283624475314%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283708165269%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283714812282%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283690728607%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283607455656%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283676476387%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283705699066%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283704201568%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283707376438%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283693308691%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283705283280%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283697105288%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283714438268%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283561149188%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283700249898%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283537473311%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283694915230%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283691540316%2CJOB_DETAILS%29,urn^%3Ali^%3Afsd_jobPostingCard^%3A%283715329157%2CJOB_DETAILS%29'
str2='urn%3Ali%3Afsd_jobPostingCard%3A%283605835026%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283677607748%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283248391847%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283702328989%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283705267885%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283624475314%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283684253710%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283714812282%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283719366796%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283704110887%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283705287579%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283719131081%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283691766063%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283691540316%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283691239727%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283709347991%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283705277986%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283721055251%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283662545243%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283711146367%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283698080926%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283709343753%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283684556536%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283714195544%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283715489136%2CJOB_DETAILS%29'
str4=data["data"]["metadata"]["jobCardPrefetchQueries"][0]["prefetchJobPostingCard"]
str1 = str1.replace( ':','%3A')

# Replace %28 with (
str1 = str1.replace( '(','%28')

# Replace %29 with )
str1 = str1.replace( ')','%29')
str1 = str1.replace(',','%2C')
complete=''
for i in str4:
    str1=i[1:]
    str1 = str1.replace( ':','%3A')

# Replace %28 with (
    str1 = str1.replace( '(','%28')

    # Replace %29 with )
    str1 = str1.replace( ')','%29')
    str1 = str1.replace(',','%2C')
    complete=complete+str1+','
print(complete)
# Out:
# urn%3Ali%3Afsd_jobPostingCard%3A%283693308691%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283704201568%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283624475314%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283248391847%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283707310354%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283719366796%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283705699066%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283694915230%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283715635585%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283697105288%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283714812282%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283605835026%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283700249898%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283607455656%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283699961159%2CJOB_DETAILS%29,urn%3Ali%3Afsd_jobPostingCard%3A%283561149188%2CJOB_D
# ...
