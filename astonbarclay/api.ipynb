# %%
import requests

url = "https://catalogue.astonbarclay.net/api/vehicle/search?exchangeonly=true"

payload = {}
headers = {
  'authority': 'catalogue.astonbarclay.net',
  'accept': 'application/json',
  'accept-language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
  'content-encoding': 'gzip',
  'content-type': 'application/json; charset=utf-8',
  'cookie': '_gid=GA1.2.184742360.1710689292; _gcl_au=1.1.977825353.1710689293; _hjSessionUser_2201904=eyJpZCI6ImE4YTk5NjJkLTM2OTAtNTVjYS1hYzVhLTcxZmFkMjVlMDUxMyIsImNyZWF0ZWQiOjE3MTA2ODkyOTM1ODcsImV4aXN0aW5nIjp0cnVlfQ==; _hjSession_2201904=eyJpZCI6ImMzNGE2M2YyLTVhZjctNDllNi04NGY0LTgyYTc3Y2JhOGRiZCIsImMiOjE3MTA2ODkyOTM1ODgsInMiOjEsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=; intercom-id-h8quur2j=532631b2-4eb5-478d-a991-29a6bb1b38e6; intercom-session-h8quur2j=; intercom-device-id-h8quur2j=336e1db8-3b48-4dd4-8f75-4955b1d540eb; _ga=GA1.1.1924197839.1710689292; _uetsid=f7b4ba20e47211eea091718f3a952390; _uetvid=f7b4ec70e47211eea7cc7777868ed50d; _hjSessionUser_2136934=eyJpZCI6Ijc4ZWEyZjA2LTE5MmYtNTMyMC1hNWNlLTNlYWNiZjZhOGM5YSIsImNyZWF0ZWQiOjE3MTA2ODkzNTcyNTYsImV4aXN0aW5nIjpmYWxzZX0=; _hjSession_2136934=eyJpZCI6IjI0MDM2M2UwLTJkOTEtNGIzMS04N2U1LTcwMTQ1NDZhNWNjMyIsImMiOjE3MTA2ODkzNTcyNTYsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=; _ga_JPKLBZY4Z9=GS1.1.1710689292.1.1.1710689357.59.0.0',
  'referer': 'https://catalogue.astonbarclay.net/vehicle-search?exchange=true',
  'sec-ch-ua': '"Not A(Brand";v="99", "Opera GX";v="107", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# [{"cardType":"e-xchange","id":97277696,"registration":"NX65TUY","account":"442002","make":"ISUZU","model":"D-MAX DIESEL","derivative":"2.5TD Utah Double Cab 4x4","mileage":129609,"mileageWarranty":true,"type":"commercial","saleId":20240319,"siteId":99,"site":{"id":99,"name":"Aston Barclay Digital","vehicles":71},"saleStart":"2024-03-19T10:30Z","lot":null,"hall":null,"transmission":"manual","firstRegistration":"2015-10-28","fuel":"Diesel","motExpiry":"2024-09-07","doors":null,"engineSize":2499,"bodyType":"Double Cab Pick-up","images":["https://abimg003.imgix.net/NX65TUY/2024-03-12/image/1a81b40a-f909-4599-94ed-ad915c1c0e1d_removebg.jpg?w=600"],"colour":"GREY","writeoffcode":"","grade":null,"nonRunner":false,"inspectionType":"Zenith","serviceHistory":"Service book 07/18 - 41K, 12/19 - 72K, 06/23 - 118K,","remarks":"1 OWNER / MOT SEP 24 / VOSA STATES 11/21 - 93K, 11/22 - 111K, 09/23 - 123K","virtual":true,"seller":"Local Dealer Part Exchange","sellerPostcode":null,"sellerStreetOne":null
# ...

# %%
import json 
cars = json.loads(response.text)
car=cars[0]
"""
'make': 'ISUZU',
 'model': 'D-MAX DIESEL',
 'lot': None,
'site': {'id': 99, 'name': 'Aston Barclay Digital', 'vehicles': 71},

'eurostatus': 5
'registration': 'NX65TUY',
'derivative': '2.5TD Utah Double Cab 4x4',
'engineSize': 2499,
'mileage': 129609,
'transmission': 'manual',
'fuel': 'Diesel',
'doors': None,
'assuredUrl': 'https://abimg002.imgix.net/7d57920f-d47e-452a-ac42-272343c608b1.pdf',
 'assuredType': 'AA Lite',
'colour': 'GREY',
car["model"]
car["site"]["name"]
car["site"]["vehicles"]
car["eurostatus"]
car["registration"]
car["derivative"]
car["engineSize"]
car["mileage"]
car["transmission"]
car["fuel"]
car["doors"]
car["assuredType"]
car["assuredUrl"]
car["colour"]
"""
data={}
data["Make"]=car["make"]
data["Model"]=car["model"]
data["Site"]=car["site"]["name"]
data["Vehicles"]=car["site"]["vehicles"]
data["Eurostatus"]=car["eurostatus"]
data["Registration"]=car["registration"]
data["Derivative"]=car["derivative"]
data["EngineSize"]=car["engineSize"]
data["Mileage"]=car["mileage"]
data["Transmission"]=car["transmission"]
data["Fuel"]=car["fuel"]
data["Doors"]=car["doors"] 
data["AssuredType"]=car["assuredType"]
data["AssuredUrl"]=car["assuredUrl"]
data["Colour"]=car["colour"]

data
# Out:
# {'Make': 'ISUZU',
#  'Model': 'D-MAX DIESEL',
#  'Site': 'Aston Barclay Digital',
#  'Vehicles': 71,
#  'Eurostatus': 5,
#  'Registration': 'NX65TUY',
#  'Derivative': '2.5TD Utah Double Cab 4x4',
#  'EngineSize': 2499,
#  'Mileage': 129609,
#  'Transmission': 'manual',
#  'Fuel': 'Diesel',
#  'Doors': None,
#  'AssuredType': 'AA Lite',
#  'AssuredUrl': 'https://abimg002.imgix.net/7d57920f-d47e-452a-ac42-272343c608b1.pdf',
#  'Colour': 'GREY'}

# %%
excelList=[]
for car in cars:
    data={}
    data["Make"]=car["make"]
    data["Model"]=car["model"]
    data["Site"]=car["site"]["name"]
    #data["Vehicles"]=car["site"]["vehicles"]
    data["Eurostatus"]=car["eurostatus"]
    data["Registration"]=car["registration"]
    data["Derivative"]=car["derivative"]
    data["EngineSize"]=car["engineSize"]
    data["Mileage"]=car["mileage"]
    data["Transmission"]=car["transmission"]
    data["Fuel"]=car["fuel"]
    data["Doors"]=car["doors"] 
    data["AssuredType"]=car["assuredType"]
    data["AssuredUrl"]=car["assuredUrl"]
    data["Colour"]=car["colour"]
    print(data)
    excelList.append(data)
# Out:
# {'Make': 'ISUZU', 'Model': 'D-MAX DIESEL', 'Site': 'Aston Barclay Digital', 'Eurostatus': 5, 'Registration': 'NX65TUY', 'Derivative': '2.5TD Utah Double Cab 4x4', 'EngineSize': 2499, 'Mileage': 129609, 'Transmission': 'manual', 'Fuel': 'Diesel', 'Doors': None, 'AssuredType': 'AA Lite', 'AssuredUrl': 'https://abimg002.imgix.net/7d57920f-d47e-452a-ac42-272343c608b1.pdf', 'Colour': 'GREY'}
# {'Make': 'HYUNDAI', 'Model': 'TUCSON DIESEL ESTATE', 'Site': 'Aston Barclay Westbury', 'Eurostatus': 6, 'Registration': 'HS16FKO', 'Derivative': '1.7 CRDi Blue Drive SE 5dr 2WD', 'EngineSize': 1685, 'Mileage': 128368, 'Transmission': 'manual', 'Fuel': 'Diesel', 'Doors': 5, 'AssuredType': 'AA Lite', 'AssuredUrl': 'https://abimg002.imgix.net/3584d908-bb0e-49bc-9d97-09877cf6a902.pdf', 'Colour': 'SILVER'}
# ...

# %%
# given data MUST be a LIST that has DICTS with same key names as ELEMENTS

#appends data to xlsx file, does not deletes the existing data
import pandas as pd
#creates a new file if the file does not exist in cd

def append_toXlsx(dictionaryList, fileName):
    try:
        df_existing = pd.read_excel(fileName)
        print(fileName + " exists")
    except:
        print("File does not exist creating file: " + fileName)
        df_existing = None
    df_new = pd.DataFrame(dictionaryList)
    df_combined = pd.concat([df_existing, df_new], ignore_index=True)
    with pd.ExcelWriter(fileName, engine="openpyxl") as writer:
        df_combined.to_excel(writer, index=False, sheet_name="Sheet")
    print("Data is appended to", fileName)


append_toXlsx(excelList, "Aston Barclay Westbury Auction.xlsx")
# Out:
# File does not exist creating file: Aston Barclay Westbury Auctions.xlsx
# Data is appended to Aston Barclay Westbury Auctions.xlsx
