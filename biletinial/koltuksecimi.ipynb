# %%
import requests
from bs4 import BeautifulSoup
url = "https://biletinial.com/tr-tr/tiyatro/tatli-kacik"

payload = {}
headers = {
  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'Accept-Language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
  'Cache-Control': 'max-age=0',
  'Connection': 'keep-alive',
  'Cookie': 'biletinial_cookie={"categories":["tanimlama","performans","pazarlama"],"level":["tanimlama","performans","pazarlama"],"revision":0,"data":null,"rfc_cookie":false,"consent_date":"2023-12-16T18:50:27.267Z","consent_uuid":"536a6b96-2f53-41ec-bbb3-f17c5b17ad7b","last_consent_update":"2023-12-16T18:50:27.267Z"}; ASP.NET_SessionId=zz0fmmnkvuycwow3pt4wbraq; NSC_joufscjmfu_iuuqt_ttm=ffffffff09081f7745525d5f4f58455e445a4a42378b; _gcl_au=1.1.1742697313.1710009730; _gid=GA1.2.1766169965.1710009731; _tt_enable_cookie=1; _ttp=a5sghx_aLOOpczu9UxuknGeZ71-; sbjs_migrations=1418474375998%3D1; sbjs_current_add=fd%3D2024-03-09%2021%3A42%3A11%7C%7C%7Cep%3Dhttps%3A%2F%2Fbiletinial.com%2Ftr-tr%7C%7C%7Crf%3Dhttps%3A%2F%2Fwww.google.com%2F; sbjs_first_add=fd%3D2024-03-09%2021%3A42%3A11%7C%7C%7Cep%3Dhttps%3A%2F%2Fbiletinial.com%2Ftr-tr%7C%7C%7Crf%3Dhttps%3A%2F%2Fwww.google.com%2F; sbjs_current=typ%3Dorganic%7C%7C%7Csrc%3Dgoogle%7C%7C%7Cmdm%3Dorganic%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29; sbjs_first=typ%3Dorganic%7C%7C%7Csrc%3Dgoogle%7C%7C%7Cmdm%3Dorganic%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29; __RequestVerificationToken=sxDnes8WcVud2z2JfZBl-g1YKZyPA_pXfYs59pKrXuR_-KtF1vIW6hTodMn71veW_67pJKln981Ikrm5t8XtHx6dA741; BLTAUTH=Afk67WiRTdlLG/2SB2jXwwqWWZ9/RAmk/QlxGPVf5IS/6HR1UACwzxEMDyKwit9RPttuN9tQgTNb7LMBKlChRWMtTatWwUskUoEnmGsJLEQ0QwU6JVQcuXsaetME/nLF; _gat_gtag_UA_37466048_1=1; _ga_PGQ7RWM6B4=GS1.1.1710009730.1.1.1710013851.0.0.0; _ga=GA1.1.1598616066.1710009731; _ga_FZYWCYYSPC=GS1.1.1710009730.1.1.1710013851.59.0.0; sbjs_udata=vst%3D11%7C%7C%7Cuip%3D%28none%29%7C%7C%7Cuag%3DMozilla%2F5.0%20%28Windows%20NT%2010.0%3B%20Win64%3B%20x64%29%20AppleWebKit%2F537.36%20%28KHTML%2C%20like%20Gecko%29%20Chrome%2F121.0.0.0%20Safari%2F537.36%20OPR%2F107.0.0.0; sbjs_session=pgs%3D1%7C%7C%7Ccpg%3Dhttps%3A%2F%2Fbiletinial.com%2Ftr-tr%2Ftiyatro%2Fdogville-dt; NSC_joufscjmfu_iuuqt_ttm=ffffffff09081f7745525d5f4f58455e445a4a42378b',
  'Referer': 'https://biletinial.com/tr-tr',
  'Sec-Fetch-Dest': 'document',
  'Sec-Fetch-Mode': 'navigate',
  'Sec-Fetch-Site': 'same-origin',
  'Sec-Fetch-User': '?1',
  'Upgrade-Insecure-Requests': '1',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0',
  'sec-ch-ua': '"Not A(Brand";v="99", "Opera GX";v="107", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

mainPage = requests.request("GET", url, headers=headers, data=payload)

soup=BeautifulSoup(mainPage.text, 'html.parser')
seances=soup.find("div",class_="ed-biletler__sehir").find_all("div",class_="ed-biletler__sehir__gun")
seance=seances[0]
seanceList=[]
for seance in seances:
    try:
        print(seance.find_all("button")[0]["data-title"])
        seanceList.append(seance.find_all("button")[0]["data-title"])        
    except:
        pass
seanceList
# Out:
# 13633980
# ['13633980']

# %%
import requests
from bs4 import BeautifulSoup

url = "https://biletinial.com/tr-tr/tiyatro/koltuk_secimi"
seanceId=seanceList[0]
payload = f'seanceId={seanceId}&IsUser=1&key='
headers = {
  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'Accept-Language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
  'Cache-Control': 'max-age=0',
  'Connection': 'keep-alive',
  'Content-Type': 'application/x-www-form-urlencoded',
  'Cookie': 'biletinial_cookie={"categories":["tanimlama","performans","pazarlama"],"level":["tanimlama","performans","pazarlama"],"revision":0,"data":null,"rfc_cookie":false,"consent_date":"2023-12-16T18:50:27.267Z","consent_uuid":"536a6b96-2f53-41ec-bbb3-f17c5b17ad7b","last_consent_update":"2023-12-16T18:50:27.267Z"}; ASP.NET_SessionId=zz0fmmnkvuycwow3pt4wbraq; NSC_joufscjmfu_iuuqt_ttm=ffffffff09081f7745525d5f4f58455e445a4a42378b; _gcl_au=1.1.1742697313.1710009730; _gid=GA1.2.1766169965.1710009731; _gat_gtag_UA_37466048_1=1; _tt_enable_cookie=1; _ttp=a5sghx_aLOOpczu9UxuknGeZ71-; sbjs_migrations=1418474375998%3D1; sbjs_current_add=fd%3D2024-03-09%2021%3A42%3A11%7C%7C%7Cep%3Dhttps%3A%2F%2Fbiletinial.com%2Ftr-tr%7C%7C%7Crf%3Dhttps%3A%2F%2Fwww.google.com%2F; sbjs_first_add=fd%3D2024-03-09%2021%3A42%3A11%7C%7C%7Cep%3Dhttps%3A%2F%2Fbiletinial.com%2Ftr-tr%7C%7C%7Crf%3Dhttps%3A%2F%2Fwww.google.com%2F; sbjs_current=typ%3Dorganic%7C%7C%7Csrc%3Dgoogle%7C%7C%7Cmdm%3Dorganic%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29; sbjs_first=typ%3Dorganic%7C%7C%7Csrc%3Dgoogle%7C%7C%7Cmdm%3Dorganic%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29; sbjs_udata=vst%3D1%7C%7C%7Cuip%3D%28none%29%7C%7C%7Cuag%3DMozilla%2F5.0%20%28Windows%20NT%2010.0%3B%20Win64%3B%20x64%29%20AppleWebKit%2F537.36%20%28KHTML%2C%20like%20Gecko%29%20Chrome%2F121.0.0.0%20Safari%2F537.36%20OPR%2F107.0.0.0; __RequestVerificationToken=sxDnes8WcVud2z2JfZBl-g1YKZyPA_pXfYs59pKrXuR_-KtF1vIW6hTodMn71veW_67pJKln981Ikrm5t8XtHx6dA741; _ga=GA1.1.1598616066.1710009731; sbjs_session=pgs%3D6%7C%7C%7Ccpg%3Dhttps%3A%2F%2Fbiletinial.com%2Ftr-tr%2FWebLogin%3FseanceId%3D13568962%26organizerType%3D2%26lang%3Dtr%26a_aid%3D%26a_bid%3D%26cinemaId%3D2957%26region%3Dtr-tr%26; _ga_PGQ7RWM6B4=GS1.1.1710009730.1.1.1710009783.0.0.0; BLTAUTH=Afk67WiRTdlLG/2SB2jXwwqWWZ9/RAmk/QlxGPVf5IS/6HR1UACwzxEMDyKwit9RPttuN9tQgTNb7LMBKlChRWMtTatWwUskUoEnmGsJLEQ0QwU6JVQcuXsaetME/nLF; _ga_FZYWCYYSPC=GS1.1.1710009730.1.1.1710009783.7.0.0; NSC_joufscjmfu_iuuqt_ttm=ffffffff09081f7745525d5f4f58455e445a4a42378b',
  'Origin': 'https://biletinial.com',
  'Referer': 'https://biletinial.com/tr-tr/WebLogin/Login',
  'Sec-Fetch-Dest': 'document',
  'Sec-Fetch-Mode': 'navigate',
  'Sec-Fetch-Site': 'same-origin',
  'Upgrade-Insecure-Requests': '1',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0',
  'sec-ch-ua': '"Not A(Brand";v="99", "Opera GX";v="107", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

seanceSeats = requests.request("POST", url, headers=headers, data=payload)
# Out:
# '\r\n\r\n<!doctype html>\r\n<html class="no-js" lang="tr">\r\n<head>\r\n    \r\n<meta charset="utf-8">\r\n<title>\r\nDOGVILLE Ankara DT Koltuk Seçimi  |  biletinial</title>\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="description" content="" />\r\n<meta name="keywords" content="" />\r\n<link rel="preconnect" href="https://fonts.googleapis.com">\r\n<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>\r\n<link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700&display=swap" rel="stylesheet">\r\n\r\n    <link rel="icon" sizes="16x16 32x32" href="https://b6s54eznn8xq.merlincdn.net/dist/assets/img/favicons/favicon.ico">\r\n    <link rel="apple-touch-icon-precomposed" href="https://b6s54eznn8xq.merlincdn.net/dist/assets/img/favicons/favicon-152.png">\r\n\r\n        <meta name="viewport" content="width=device-width,initial-scale=1" />\r\n        <meta property="twitter:site" content="biletinial" />\r\n\r\n\r\n<meta pr
# ...

# %%
seanceSeats = BeautifulSoup(seanceSeats.text, 'html.parser')
seatRows=soup.find('div', class_='koltuklar').find_all('div', class_='koltuk_sira')
seatRow=seatRows[7]
seatRow.find_all('span', class_="koltuk_tek normal-koltuk")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 2
#       1 seanceSeats = BeautifulSoup(seanceSeats.text, 'html.parser')
# ----> 2 seatRows=soup.find('div', class_='koltuklar').find_all('div', class_='koltuk_sira')
#       3 seatRow=seatRows[7]
#       4 seatRow.find_all('span', class_="koltuk_tek normal-koltuk")
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
import requests

url = "https://biletinial.com/dynamic/addtobasket"
seatId=8153829
payload = f"seatId={seatId}&seanceId={seanceId}&sessionId=16fe2fb3-7487-4cda-aaec-48d22a1c8838&cinemaBranchId=14327&__RequestVerificationToken=ZJxghb30PmL0r0BhmXYwAK2V8306aYNuITaAYZBj3AT5yi9DZ9Fi9s_GebLbB46E5_35jQwLvUDrLGJs8-6RSWKwo601"
headers = {
  'Accept': '*/*',
  'Accept-Language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
  'Connection': 'keep-alive',
  'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
  'Cookie': 'biletinial_cookie={"categories":["tanimlama","performans","pazarlama"],"level":["tanimlama","performans","pazarlama"],"revision":0,"data":null,"rfc_cookie":false,"consent_date":"2023-12-16T18:50:27.267Z","consent_uuid":"536a6b96-2f53-41ec-bbb3-f17c5b17ad7b","last_consent_update":"2023-12-16T18:50:27.267Z"}; ASP.NET_SessionId=zz0fmmnkvuycwow3pt4wbraq; NSC_joufscjmfu_iuuqt_ttm=ffffffff09081f7745525d5f4f58455e445a4a42378b; _gcl_au=1.1.1742697313.1710009730; _gid=GA1.2.1766169965.1710009731; _tt_enable_cookie=1; _ttp=a5sghx_aLOOpczu9UxuknGeZ71-; sbjs_migrations=1418474375998%3D1; sbjs_current_add=fd%3D2024-03-09%2021%3A42%3A11%7C%7C%7Cep%3Dhttps%3A%2F%2Fbiletinial.com%2Ftr-tr%7C%7C%7Crf%3Dhttps%3A%2F%2Fwww.google.com%2F; sbjs_first_add=fd%3D2024-03-09%2021%3A42%3A11%7C%7C%7Cep%3Dhttps%3A%2F%2Fbiletinial.com%2Ftr-tr%7C%7C%7Crf%3Dhttps%3A%2F%2Fwww.google.com%2F; sbjs_current=typ%3Dorganic%7C%7C%7Csrc%3Dgoogle%7C%7C%7Cmdm%3Dorganic%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29; sbjs_first=typ%3Dorganic%7C%7C%7Csrc%3Dgoogle%7C%7C%7Cmdm%3Dorganic%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29; __RequestVerificationToken=sxDnes8WcVud2z2JfZBl-g1YKZyPA_pXfYs59pKrXuR_-KtF1vIW6hTodMn71veW_67pJKln981Ikrm5t8XtHx6dA741; BLTAUTH=Afk67WiRTdlLG/2SB2jXwwqWWZ9/RAmk/QlxGPVf5IS/6HR1UACwzxEMDyKwit9RPttuN9tQgTNb7LMBKlChRWMtTatWwUskUoEnmGsJLEQ0QwU6JVQcuXsaetME/nLF; _ga_FZYWCYYSPC=GS1.1.1710009730.1.1.1710010330.60.0.0; _gat_gtag_UA_37466048_1=1; _ga_PGQ7RWM6B4=GS1.1.1710009730.1.1.1710010331.0.0.0; _ga=GA1.1.1598616066.1710009731; sbjs_udata=vst%3D3%7C%7C%7Cuip%3D%28none%29%7C%7C%7Cuag%3DMozilla%2F5.0%20%28Windows%20NT%2010.0%3B%20Win64%3B%20x64%29%20AppleWebKit%2F537.36%20%28KHTML%2C%20like%20Gecko%29%20Chrome%2F121.0.0.0%20Safari%2F537.36%20OPR%2F107.0.0.0; sbjs_session=pgs%3D1%7C%7C%7Ccpg%3Dhttps%3A%2F%2Fbiletinial.com%2Ftr-tr; NSC_joufscjmfu_iuuqt_ttm=ffffffff09081f7745525d5f4f58455e445a4a42378b',
  'Origin': 'https://biletinial.com',
  'Referer': 'https://biletinial.com/tr-tr/tiyatro/koltuk_secimi',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0',
  'X-Requested-With': 'XMLHttpRequest',
  'sec-ch-ua': '"Not A(Brand";v="99", "Opera GX";v="107", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"Prices":null,"Currency":{"ID":2,"Name":"Türk Lirası","CurrencyCode":"TL","CurrencySymbol":"₺","MoneyCode":"949"},"Success":false,"StatusCode":null,"Message":"Etkinlik 10 Mart 2024 Pazar 10:10 tarihinde satışa açılacaktır."}
