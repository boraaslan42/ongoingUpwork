# %%
import requests

# Create a session and set user agent
session = requests.Session()
session.headers.update({"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0"})

# Set cookies
cookies = {
    "AnonymousId": "795a3f18c98c486b99a1a86d17e294e1",
    "ll-search-selection": "",
    ".AspNetCore.Session": "CfDJ8K4bVR7RO11Hm8yVKoXBt3jz%2BGpEVtYA%2FK6M7woicwSvCIjJdoPkdQBieUfKNI1Mf09V%2FhAo6Zt30yp2T02RwHpqyH3E4W5YK2ERZwlEeKjpQAyWVJQUXyFvqzBo0THjgMqMPIOC3xXHW%2BsDATI3X3YLaAT0eZRm52aCPZ46JU7u",
    "didomi_token": "...",
    "euconsent-v2": "CP7g5sAP7g5sAAHABBENArEgAP_AAELAAAAAF5wAgAmgLzAvOACAvMAA.f_gACFgAAAAA",
    "_gcl_au": "1.1.16334783.1710520934",
    "_ga": "GA1.1.1694716223.1710520914",
    "_pin_unauth": "dWlkPU1UaGxOVEl5TmpFdE1UQmxZeTAwTW1abExUazNNMlV0TlRjMllXWm1ZamN6WW1Saw",
    "_hjSessionUser_3464907": "eyJpZCI6IjA1NDdkMzVkLTg5MzktNWQ5Zi1hNDczLWM0YmY2YTU0MzM3ZiIsImNyZWF0ZWQiOjE3MTA1MjA5MzQ2NzYsImV4aXN0aW5nIjp0cnVlfQ==",
    "ll-visitor-id": "583b5a83-dd9a-4a4c-9298-9712be07b31f",
    "_ga_2BZHP07X6B": "GS1.1.1710530378.2.0.1710530378.60.0.0",
    "_derived_epik": "dj0yJnU9Ry1GajB4RzN6eEk0Mm8yUEVSYkdBdVc0RjdSTVQtWmMmbj1seXdxdUdKM0RUSjE4MHRoeVppRFF3Jm09MSZ0PUFBQUFBR1gwbjBvJnJtPTEmcnQ9QUFBQUFHWDBuMG8mc3A9Mg",
    "_hjSession_3464907": "eyJpZCI6ImYxNmM5MjU2LWEyNDYtNDI4Mi1hNWQ2LWQ1ZGJkYTZkNjZhNyIsImMiOjE3MTA1MzAzNzkxMDYsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0="
}
session.cookies.update(cookies)

# Define headers
headers = {
    "authority": "www.centris.ca",
    "accept": "application/json, text/javascript, */*; q=0.01",
    "accept-language": "tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7",
    "cache-control": "no-cache",
    "origin": "https://www.centris.ca",
    "referer": "https://www.centris.ca/en/properties~for-sale?view=Thumbnail&uc=1",
    "sec-ch-ua": '"Not A(Brand";v="99", "Opera GX";v="107", "Chromium";v="121"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-centris-uc": "1",
    "x-centris-uck": "9fd6469d-7a27-4faf-b455-142ac40aef0a",
    "x-requested-with": "XMLHttpRequest"
}

# Define JSON data
data = {"startPosition": 20}

# Send POST request
response = session.post("https://www.centris.ca/Property/GetInscriptions", headers=headers, json=data)
print(response.text)
# Out:
# {"d":{"Message":"","Result":{"html":"\r\n    <div class=\"property-thumbnail-item thumbnailItem col-12 col-sm-6 col-md-4 col-lg-3\" itemscope itemtype=\"http://schema.org/Product\">\r\n        <div class=\"shell\">\r\n            \r\n\r\n\r\n\r\n    <div class=\"thumbnail property-thumbnail-feature legacy-reset\">\r\n        <meta content=\"Lot for sale in Gracefield, Outaouais, Chemin Whyte, 24590872 - Centris.ca\" itemprop=\"name\" />\r\n        <meta content=\"24590872\" itemprop=\"sku\" />\r\n        <a class=\"property-thumbnail-summary-link\" href=\"/en/lots~for-sale~gracefield/24590872?view=Summary&amp;uc=1\">\r\n            <img itemprop=\"image\" src=\"https://mspublic.centris.ca/media.ashx?id=ADDD250DC5FB1A8DDDDDDDDDDF&amp;t=pi&amp;w=320&amp;h=240&amp;sm=c\" alt=\"Lot for sale in Gracefield, Outaouais, Chemin Whyte, 24590872 - Centris.ca\" />\r\n        </a>\r\n\r\n        <div class=\"photo-buttons \">\r\n                <button class=\"btn photo-btn\" onclick=\"event.prev
# ...

# %%
import requests

headers = {
    'authority': 'www.centris.ca',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'no-cache',
    'content-type': 'application/json; charset=UTF-8',
    'cookie': 'AnonymousId=795a3f18c98c486b99a1a86d17e294e1; ll-search-selection=; .AspNetCore.Session=CfDJ8K4bVR7RO11Hm8yVKoXBt3jz+GpEVtYA/K6M7woicwSvCIjJdoPkdQBieUfKNI1Mf09V/hAo6Zt30yp2T02RwHpqyH3E4W5YK2ERZwlEeKjpQAyWVJQUXyFvqzBo0THjgMqMPIOC3xXHW+sDATI3X3YLaAT0eZRm52aCPZ46JU7u; didomi_token=...; euconsent-v2=CP7g5sAP7g5sAAHABBENArEgAP_AAELAAAAAF5wAgAmgLzAvOACAvMAA.f_gACFgAAAAA; _gcl_au=1.1.16334783.1710520934; _ga=GA1.1.1694716223.1710520914; _pin_unauth=dWlkPU1UaGxOVEl5TmpFdE1UQmxZeTAwTW1abExUazNNMlV0TlRjMllXWm1ZamN6WW1Saw; _hjSession_3464907=eyJpZCI6IjAzZWZiZGRkLWYwOWEtNDBiZC1hYzYxLWQxYzI4M2NlZTczNyIsImMiOjE3MTA1MjA5MzQ2NzcsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MX0=; _hjSessionUser_3464907=eyJpZCI6IjA1NDdkMzVkLTg5MzktNWQ5Zi1hNDczLWM0YmY2YTU0MzM3ZiIsImNyZWF0ZWQiOjE3MTA1MjA5MzQ2NzYsImV4aXN0aW5nIjp0cnVlfQ==; ll-visitor-id=583b5a83-dd9a-4a4c-9298-9712be07b31f; _ga_2BZHP07X6B=GS1.1.1710520913.1.1.1710523676.59.0.0; _derived_epik=dj0yJnU9VFAyU3VCUjAyRkZfdGREUmJwTy16V01SSDhTLWxKbFombj1BbmctMDJwbkg4cGlPVzBiOEZmSnBBJm09MSZ0PUFBQUFBR1gwaFJ3JnJtPTEmcnQ9QUFBQUFHWDBoUncmc3A9Mg',
    'origin': 'https://www.centris.ca',
    'referer': 'https://www.centris.ca/en/properties~for-sale?view=Thumbnail&uc=1',
    'sec-ch-ua': '"Not A;Brand";v="99", "Opera GX";v="107", "Chromium";v="121"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0',
    'x-centris-uc': '1',
    'x-centris-uck': '5e536065-2c07-495e-a668-1e09943ec638',
    'x-requested-with': 'XMLHttpRequest',
}

data = '{"startPosition":12}'

response = requests.post('https://www.centris.ca/Property/GetInscriptions', headers=headers, data=data)
print(response)
# Out:
# <Response [555]>

# %%
import requests

url = "https://www.centris.ca/Property/GetInscriptions"

payload = "{\"startPosition\":20}"
headers = {
  'authority': 'www.centris.ca',
  'accept': 'application/json, text/javascript, */*; q=0.01',
  'accept-language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control': 'no-cache',
  'content-type': 'application/json; charset=UTF-8',
  'cookie': 'AnonymousId=795a3f18c98c486b99a1a86d17e294e1; ll-search-selection=; .AspNetCore.Session=CfDJ8K4bVR7RO11Hm8yVKoXBt3jz%2BGpEVtYA%2FK6M7woicwSvCIjJdoPkdQBieUfKNI1Mf09V%2FhAo6Zt30yp2T02RwHpqyH3E4W5YK2ERZwlEeKjpQAyWVJQUXyFvqzBo0THjgMqMPIOC3xXHW%2BsDATI3X3YLaAT0eZRm52aCPZ46JU7u; didomi_token=...; euconsent-v2=CP7g5sAP7g5sAAHABBENArEgAP_AAELAAAAAF5wAgAmgLzAvOACAvMAA.f_gACFgAAAAA; _gcl_au=1.1.16334783.1710520934; _ga=GA1.1.1694716223.1710520914; _pin_unauth=dWlkPU1UaGxOVEl5TmpFdE1UQmxZeTAwTW1abExUazNNMlV0TlRjMllXWm1ZamN6WW1Saw; _hjSessionUser_3464907=eyJpZCI6IjA1NDdkMzVkLTg5MzktNWQ5Zi1hNDczLWM0YmY2YTU0MzM3ZiIsImNyZWF0ZWQiOjE3MTA1MjA5MzQ2NzYsImV4aXN0aW5nIjp0cnVlfQ==; ll-visitor-id=583b5a83-dd9a-4a4c-9298-9712be07b31f; _ga_2BZHP07X6B=GS1.1.1710530378.2.0.1710530378.60.0.0; _derived_epik=dj0yJnU9Ry1GajB4RzN6eEk0Mm8yUEVSYkdBdVc0RjdSTVQtWmMmbj1seXdxdUdKM0RUSjE4MHRoeVppRFF3Jm09MSZ0PUFBQUFBR1gwbjBvJnJtPTEmcnQ9QUFBQUFHWDBuMG8mc3A9Mg; _hjSession_3464907=eyJpZCI6ImYxNmM5MjU2LWEyNDYtNDI4Mi1hNWQ2LWQ1ZGJkYTZkNjZhNyIsImMiOjE3MTA1MzAzNzkxMDYsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; .AspNetCore.Session=CfDJ8LcCKoU0iu9EtE3Fsett9d4dJfjv%2BLBl1WsAG8pb7U7yJa7K5fNLF%2FXldw5hJwXOFpW8Tw1irLNvvXDD0O9ZqXKvE%2B5QNweZPacfvq3lrcf%2BhgV5GJS3K35%2BvmbpB5SYPfpEvRIw1lKjCAxzeLjkGq7dV6FbXEQEZ47tyQZ9EjgU; ll-search-selection=',
  'origin': 'https://www.centris.ca',
  'referer': 'https://www.centris.ca/en/properties~for-sale?view=Thumbnail&uc=1',
  'sec-ch-ua': '"Not A(Brand";v="99", "Opera GX";v="107", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0',
  'x-centris-uc': '1',
  'x-centris-uck': '9fd6469d-7a27-4faf-b455-142ac40aef0a',
  'x-requested-with': 'XMLHttpRequest'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)

# %%
response.text
# Out:
# ''

# %%
def append_toXlsx(dictionaryList, fileName):
    try:
        df_existing = pd.read_excel(fileName)
        print(fileName + " exists")
    except:
        print("File does not exist creating file: " + fileName)
        df_existing = None
    df_new = pd.DataFrame(dictionaryList)
    df_combined = pd.concat([df_existing, df_new], ignore_index=True)
    with pd.ExcelWriter(fileName, engine="openpyxl") as writer:
        df_combined.to_excel(writer, index=False, sheet_name="Sheet")
    print("Data is appended to", fileName)

# %%
import json
from bs4 import BeautifulSoup
json_data = json.loads(response.text)
soup=BeautifulSoup(json_data["d"]["Result"]["html"], 'html.parser')

#<div class="property-thumbnail-item
houses=soup.find_all("div", class_="property-thumbnail-item")
house=houses[0]

for house in houses:
    detailUrl="https://www.centris.ca/"+house.find("a", class_="a-more-detail" )["href"]
    address=[x.text for x in house.find_all("span")[3].find_all("div")]
    info1=", ".join(address)
    price=house.span
    Address=house.find_all("meta")[0]
    Sku=house.find_all("meta")[1]
    bathroomsqft=house.find("div",class_="d-flex justify-content-start flex-wrap features").find_all("div")
    details=""
    #print(bathroomsqft)
    for info in bathroomsqft:
        #print(info["class"])
        if info["class"][0]=="cac":
            details+="Amount of bedrooms: "+info.text+" "
        elif info["class"][0]=="sdb":
            details+="Amount of bathrooms: "+info.text    
        elif info["class"][0]=="land-area":
            details+="Land Area: "+info.text.strip()  
    data={}
    
    data["price"]=price.text
    data["Listing Type"]=Address["content"].split("in")[0]
    data["Adress"]=info1
    data["SKU"]=Sku["content"]
    data["Details"]=details
    print(data)
# Out:
# {'price': '$825,000', 'Listing Type': 'Condo for sale ', 'Adress': '3950, Rue Claude-Henri-Grignon, apt. 114, Montréal (Saint-Laurent), Neighbourhood New Saint-Laurent/Bois-Franc', 'SKU': '13562670', 'Details': 'Amount of bedrooms: 4 Amount of bathrooms: 3'}
# {'price': '$319,900', 'Listing Type': 'Condo for sale ', 'Adress': '4820, 4e Avenue, apt. 315, Montréal (Rosemont/La Petite-Patrie), Neighbourhood Shop Angus', 'SKU': '23339382', 'Details': 'Amount of bedrooms: 1 Amount of bathrooms: 1'}
# {'price': '$293,900', 'Listing Type': 'Condo for sale ', 'Adress': '4904, Rue Sainte-Catherine Est, apt. 201, Montréal (Mercier/Hochelaga-Maisonneuve), Neighbourhood Hochelaga-Maisonneuve', 'SKU': '13143386', 'Details': 'Amount of bedrooms: 1 Amount of bathrooms: 1'}
# ...

# %%
import json
import requests
import pandas as pd
from bs4 import BeautifulSoup
excelList=[]
def getPage(pageNo):
    pageNo=(pageNo-1)*12

    url = "https://www.centris.ca/Property/GetInscriptions"

    headers = {
        "authority": "www.centris.ca",
        "accept": "application/json, text/javascript, */*; q=0.01",
        "accept-language": "tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7",
        "cache-control": "no-cache",
        "content-type": "application/json; charset=UTF-8",
        "cookie": "AnonymousId=795a3f18c98c486b99a1a86d17e294e1; ll-search-selection=; .AspNetCore.Session=CfDJ8K4bVR7RO11Hm8yVKoXBt3jz+GpEVtYA/K6M7woicwSvCIjJdoPkdQBieUfKNI1Mf09V/hAo6Zt30yp2T02RwHpqyH3E4W5YK2ERZwlEeKjpQAyWVJQUXyFvqzBo0THjgMqMPIOC3xXHW+sDATI3X3YLaAT0eZRm52aCPZ46JU7u; didomi_token=...; euconsent-v2=CP7g5sAP7g5sAAHABBENArEgAP_AAELAAAAAF5wAgAmgLzAvOACAvMAA.f_gACFgAAAAA; _gcl_au=1.1.16334783.1710520934; _ga=GA1.1.1694716223.1710520914; _pin_unauth=dWlkPU1UaGxOVEl5TmpFdE1UQmxZeTAwTW1abExUazNNMlV0TlRjMllXWm1ZamN6WW1Saw; _hjSession_3464907=eyJpZCI6IjAzZWZiZGRkLWYwOWEtNDBiZC1hYzYxLWQxYzI4M2NlZTczNyIsImMiOjE3MTA1MjA5MzQ2NzcsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MX0=; _hjSessionUser_3464907=eyJpZCI6IjA1NDdkMzVkLTg5MzktNWQ5Zi1hNDczLWM0YmY2YTU0MzM3ZiIsImNyZWF0ZWQiOjE3MTA1MjA5MzQ2NzYsImV4aXN0aW5nIjp0cnVlfQ==; ll-visitor-id=583b5a83-dd9a-4a4c-9298-9712be07b31f; _ga_2BZHP07X6B=GS1.1.1710520913.1.1.1710523676.59.0.0; _derived_epik=dj0yJnU9VFAyU3VCUjAyRkZfdGREUmJwTy16V01SSDhTLWxKbFombj1BbmctMDJwbkg4cGlPVzBiOEZmSnBBJm09MSZ0PUFBQUFBR1gwaFJ3JnJtPTEmcnQ9QUFBQUFHWDBoUncmc3A9Mg",
        "origin": "https://www.centris.ca",
        "referer": "https://www.centris.ca/en/properties~for-sale?view=Thumbnail&uc=1",
        "sec-ch-ua": '"Not A(Brand";v="99", "Opera GX";v="107", "Chromium";v="121"',
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": '"Windows"',
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0",
        "x-centris-uc": "1",
        "x-centris-uck": "5e536065-2c07-495e-a668-1e09943ec638",
        "x-requested-with": "XMLHttpRequest",
    }

    #data = f'{"startPosition":pageNo}'
    
    data = {"startPosition":str(pageNo)}
    
    response = requests.post(url, headers=headers, data=str(data))
    json_data = json.loads(response.text)
    soup=BeautifulSoup(json_data["d"]["Result"]["html"], 'html.parser')

    #<div class="property-thumbnail-item
    houses=soup.find_all("div", class_="property-thumbnail-item")
    house=houses[0]

    for house in houses:
        detailUrl="https://www.centris.ca/"+house.find("a", class_="a-more-detail" )["href"]
        address=[x.text for x in house.find_all("span")[3].find_all("div")]
        info1=", ".join(address)
        price=house.span
        Address=house.find_all("meta")[0]
        Sku=house.find_all("meta")[1]
        bathroomsqft=house.find("div",class_="d-flex justify-content-start flex-wrap features").find_all("div")
        details=""
        #print(bathroomsqft)
        for info in bathroomsqft:
            #print(info["class"])
            if info["class"][0]=="cac":
                details+="Amount of bedrooms: "+info.text+" "
            elif info["class"][0]=="sdb":
                details+="Amount of bathrooms: "+info.text    
            elif info["class"][0]=="land-area":
                details+="Land Area: "+info.text.strip()  
        data={}
        
        data["price"]=price.text
        data["Listing Type"]=Address["content"].split("in")[0]
        data["Adress"]=info1
        data["SKU"]=Sku["content"]
        data["Details"]=details
        excelList.append(data)
        print(data)
    

getPage(1)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[31], line 73
#      69         excelList.append(data)
#      70         print(data)
# ---> 73 getPage(1)
#
# Cell In[31], line 37, in getPage(pageNo)
#      34 data = {"startPosition":str(pageNo)}
#      36 response = requests.post(url, headers=headers, data=str(data))
# ---> 37 json_data = json.loads(response.text)
#      38 soup=BeautifulSoup(json_data["d"]["Result"]["html"], 'html.parser')
#      40 #<div class="property-thumbnail-item
#
# File c:\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
# ...

# %%
excelList=[]
for i in range(1,10):
    getPage(i)
# Out:
# {'price': '$825,000', 'Listing Type': 'Condo for sale ', 'Adress': '3950, Rue Claude-Henri-Grignon, apt. 114, Montréal (Saint-Laurent), Neighbourhood New Saint-Laurent/Bois-Franc', 'SKU': '13562670', 'Details': 'Amount of bedrooms: 4 Amount of bathrooms: 3'}
# {'price': '$319,900', 'Listing Type': 'Condo for sale ', 'Adress': '4820, 4e Avenue, apt. 315, Montréal (Rosemont/La Petite-Patrie), Neighbourhood Shop Angus', 'SKU': '23339382', 'Details': 'Amount of bedrooms: 1 Amount of bathrooms: 1'}
# {'price': '$293,900', 'Listing Type': 'Condo for sale ', 'Adress': '4904, Rue Sainte-Catherine Est, apt. 201, Montréal (Mercier/Hochelaga-Maisonneuve), Neighbourhood Hochelaga-Maisonneuve', 'SKU': '13143386', 'Details': 'Amount of bedrooms: 1 Amount of bathrooms: 1'}
# ...

# %%
append_toXlsx(excelList, "centrisData first 10 pages.xlsx")
# Out:
# File does not exist creating file: centrisData first 10 pages.xlsx
# Data is appended to centrisData first 10 pages.xlsx

# %%
for i in excelList[:8]:
    print("Price:",i["price"],"Address:",i["Adress"])
# Out:
# Price: $825,000 Address: 3950, Rue Claude-Henri-Grignon, apt. 114, Montréal (Saint-Laurent), Neighbourhood New Saint-Laurent/Bois-Franc
# Price: $319,900 Address: 4820, 4e Avenue, apt. 315, Montréal (Rosemont/La Petite-Patrie), Neighbourhood Shop Angus
# Price: $293,900 Address: 4904, Rue Sainte-Catherine Est, apt. 201, Montréal (Mercier/Hochelaga-Maisonneuve), Neighbourhood Hochelaga-Maisonneuve
# Price: $172,900 Address: Chemin Rhéaume, Sherbrooke (Brompton/Rock Forest/Saint-Élie/Deauville), Neighbourhood Saint-Élie d'Orford
# Price: $2,249,000 Address: 171, Chemin Owl's Head, Potton
# Price: $95,000 Address: Chemin Beauséjour, Rimouski, Neighbourhood Sainte-Odile
# Price: $639,000 Address: 1110, Rang Sainte-Croix, Saint-Raymond
# Price: $154,500 Address: 3635 - 3639, Rue du Roi-Georges, Saguenay (Jonquière), Neighbourhood Arvida
