# %%
import requests

def gettime(ID):
    url = f"http://www.watchcount.com/mw2.php?bkw={ID}&bcat=0&bcts=&sfsb=Show+Me%21&csbin=all&bslr=&bnp=&bxp="

    payload = {}
    headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Cookie': 'PHPSESSID=b15tduvs1kpb86tpgmh8u9j0e7; uid=b15tduvs1kpb; cc=US; _ga=GA1.1.1351098068.1709899817; LSFS=none; sc_is_visitor_unique=rx1998325.1709900203.5E433E0D1CC84F1E83FAE25A5BEBF098.1.1.1.1.1.1.1.1.1; _ga_BY9CK6LM7X=GS1.1.1709899817.1.1.1709900202.0.0.0',
    'Referer': 'http://www.watchcount.com/mw2.php?bkw=276371314021&bcat=0&bcts=&sfsb=Show+Me%21&csbin=all&bslr=&bnp=&bxp=',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0'
    }

    response = requests.request("GET", url, headers=headers, data=payload)

    from bs4 import BeautifulSoup
    soup=BeautifulSoup(response.text, 'html.parser')
    table=soup.find("td", class_="ilu-data").find_all("tr")
    x=table[8].find_all("td")
    print("Name of product:",soup.find("a",class_="links").span.text)
    
    print("Url of product: https://www.ebay.com/itm/"+str(ID))
    print("Id of product:",ID)
    for i in x:
        print(i.text.strip(),end=" ")


IDlist=[276371327151,276371314021,134927863552,354593770099,274493598619]
for ID in IDlist:
    gettime(ID)
    print("\n")
    
    
IDlist=[276371327151,276371314021,134927863552,354593770099,274493598619]
# Out:
# Name of product: Campingofen {"Camping Stove":"Campingofen"} Edelstahl Kupfer Propan Brandneu
# Url of product: https://www.ebay.com/itm/276371327151
# Id of product: 276371327151
# Start Time: Friday, 08-Mar-24 12:08:59 UTC
#
# Name of product: Anti-Kratzer Reflektierender Streifen Zur Sicherheit Wasserdichtes Nylon
# Url of product: https://www.ebay.com/itm/276371314021
# Id of product: 276371314021
# Start Time: Friday, 08-Mar-24 11:56:45 UTC
#
# Name of product: Vergaser Membransatz Dichtung für Walbro K11-WAT Stihl 021 023 026 MS FS Partner
# Url of product: https://www.ebay.com/itm/134927863552
# Id of product: 134927863552
# Start Time: Friday, 09-Feb-24 01:40:33 UTC
#
# Name of product: Apple iPhone 13 Pro Max, A2484, 256GB, Unlocked, Excellent Condition
# Url of product: https://www.ebay.com/itm/354593770099
# Id of product: 354593770099
# Start Time: Saturday, 18-Feb-23 00:12:35 UTC
#
# ...

# %%
from ebaysdk.shopping import Connection as Shopping

# Initialize the eBay API client
api = Shopping(domain='api.ebay.com', appid='BoraAsla-listingt-SBX-d221fff64-2b217ae7', siteid='EBAY-US', config_file=None)

# Set the authentication token


# Define the item ID
item_id = 'YourItemID'


# Make the API request to get item details
response = api.execute('GetSingleItem', {'ItemID': item_id})


# Parse the response to get the listing date
listing_date = response.dict()['Item']['ListingDetails']['StartTime']
print("Listing Date:", listing_date)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[20], line 14
#      10 item_id = 'YourItemID'
#      13 # Make the API request to get item details
# ---> 14 response = api.execute('GetSingleItem', {'ItemID': item_id})
#      17 # Parse the response to get the listing date
#      18 listing_date = response.dict()['Item']['ListingDetails']['StartTime']
#
# File c:\Python311\Lib\site-packages\ebaysdk\connection.py:127, in BaseConnection.execute(self, verb, data, list_nodes, verb_attrs, files)
#     125 if hasattr(self.response, 'content'):
#     126     self.process_response()
# --> 127     self.error_check()
#     129 log.debug('total time=%s' % (time.time() - self._time))
#     131 return self.response
#
# File c:\Python311\Lib\site-packages\ebaysdk\connection.py:223, in BaseConnection.error_check(self)
#     221 if estr and self.config.get('errors', True):
# ...

# %%
import requests
headers = {
"Authorization":"Bearer v^1.1#i^1#f^0#p^1#I^3#r^0#t^...",
"X-EBAY-C-MARKETPLACE-ID":"EBAY_US",
"X-EBAY-C-ENDUSERCTX":"contextualLocation=country=<2_character_country_code>,zip=<zip_code>,affiliateCampaignId=<ePNCampaignId>,affiliateReferenceId=<referenceId>"
}
item_id = "276015021037"
legacy_item_id="276015021037"
url=f"https://api.ebay.com/buy/browse/v1/item/{item_id}?fieldgroups=COMPACT"
url2=f"https://api.ebay.com/buy/browse/v1/item/get_item_by_legacy_id?legacy_item_id={legacy_item_id}"
print(url)
response = requests.request("GET", url, headers=headers)
response2 = requests.request("GET", url2, headers=headers)
print(response.text)
response2.json()
# Out:
# https://api.ebay.com/buy/browse/v1/item/276015021037?fieldgroups=COMPACT
# {"errors":[{"errorId":11001,"domain":"API_BROWSE","category":"REQUEST","message":"The specified item Id was not found."}]}
# {'itemId': 'v1|276015021037|0',
#  'sellerItemRevision': '2842',
#  'title': 'Sony WF-1000XM5 Truly Wireless Bluetooth Noise Canceling Headphones - Black',
#  'subtitle': 'Certified Refurbished, Free Shipping, 30 Day Returns',
#  'shortDescription': 'The WF-1000XM5 reduces external noise over a wide bandwidth, from low to high frequencies. Mute the outside world with Precise Voice Pickup Technology and advanced audio signal processing. The person on the other end of the call will hear your voice clearly, even when you are in noisy situations.',
#  'price': {'value': '139.99', 'currency': 'USD'},
#  'categoryPath': 'Consumer Electronics|Portable Audio & Headphones|Headphones',
#  'categoryIdPath': '293|15052|112529',
#  'condition': 'Certified - Refurbished',
#  'conditionId': '2000',
# ...

# %%
# Out:
# <?xml version="1.0" encoding="UTF-8" ?><GetSingleItemResponse xmlns="urn:ebay:apis:eBLBaseComponents"><Timestamp>2024-03-09 14:21:11</Timestamp><Ack>Failure</Ack><Errors><ShortMessage>Unsupported API call.</ShortMessage><LongMessage>The API call "GetSingleItem" is invalid or not supported in this release.</LongMessage><ErrorCode>2</ErrorCode><SeverityCode>Error</SeverityCode><ErrorClassification>RequestError</ErrorClassification></Errors><Build>19110890</Build></GetSingleItemResponse>

# %%
import requests
headers = {
"Authorization":"Bearer v^1.1#i^1#f^0#p^1#I^3#r^0#t^...",
"X-EBAY-C-MARKETPLACE-ID":"EBAY_US",
"X-EBAY-C-ENDUSERCTX":"contextualLocation=country=<2_character_country_code>,zip=<zip_code>,affiliateCampaignId=<ePNCampaignId>,affiliateReferenceId=<referenceId>"
}
# Define API endpoint and parameters
url = "https://open.api.ebay.com/shopping"
params = {
    "callname": "GetSingleItem",
    "responseencoding": "XML",
    "siteid": 0,
    "version": 967,
    "ItemID": "1**********1"  # Replace this with the actual ItemID
}

# Make the request
response = requests.get(url, headers=headers,params=params,)

# Check if the request was successful
if response.status_code == 200:
    # Print the response content
    print(response.text)
else:
    print("Error:", response.status_code)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
#
#   <GetSingleItemResponse xmlns="urn:ebay:apis:eBLBaseComponents">
#    <Timestamp>2024-03-09T13:48:47.326Z</Timestamp>
#    <Ack>Failure</Ack>
#    <Errors>
#     <ShortMessage>Token not available in request.</ShortMessage>
#     <LongMessage>Token not available in request. Please specify a valid token as HTTP header.</LongMessage>
#     <ErrorCode>1.33</ErrorCode>
#     <SeverityCode>Error</SeverityCode>
#     <ErrorClassification>RequestError</ErrorClassification>
#    </Errors>
#    <Build>1299_CORE_APILW_19146596_R1</Build>
#    <Version>1299</Version>
#   </GetSingleItemResponse>

# %%
from ebaysdk.shopping import Connection as Shopping

# Initialize the eBay Shopping API connection
api = Shopping(appid='BoraAsla-listingt-PRD-2220d980b-744fb821', siteid='EBAY_US', config_file=None)

# Specify the ItemID you want to retrieve information about
item_id = '1**********1'  # Replace this with the actual ItemID

# Make the API call to get information about the single item
response = api.execute('GetSingleItem', {'ItemID': item_id})

# Check if the request was successful
if response.reply.Ack == 'Success':
    # Print information about the item
    item = response.reply.Item
    print("Title:", item.Title)
    print("Price:", item.ConvertedCurrentPrice.Value, item.ConvertedCurrentPrice.CurrencyID)
    print("Location:", item.Location)
    # Add more attributes as needed
else:
    print("Error:", response.dict())
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[52], line 10
#       7 item_id = '1**********1'  # Replace this with the actual ItemID
#       9 # Make the API call to get information about the single item
# ---> 10 response = api.execute('GetSingleItem', {'ItemID': item_id})
#      12 # Check if the request was successful
#      13 if response.reply.Ack == 'Success':
#      14     # Print information about the item
#
# File c:\Python311\Lib\site-packages\ebaysdk\connection.py:127, in BaseConnection.execute(self, verb, data, list_nodes, verb_attrs, files)
#     125 if hasattr(self.response, 'content'):
#     126     self.process_response()
# --> 127     self.error_check()
#     129 log.debug('total time=%s' % (time.time() - self._time))
#     131 return self.response
#
# File c:\Python311\Lib\site-packages\ebaysdk\connection.py:223, in BaseConnection.error_check(self)
# ...
