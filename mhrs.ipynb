# %%
import requests
import json

url = "https://prd.mhrs.gov.tr/api/kurum-rss/randevu/slot-sorgulama/arama"

payload = json.dumps({
  "aksiyonId": "200",
  "cinsiyet": "F",
  "mhrsHekimId": -1,
  "mhrsIlId": 34,
  "mhrsIlceId": -1,
  "mhrsKlinikId": 181,
  "mhrsKurumId": -1,
  "muayeneYeriId": -1,
  "tumRandevular": False,
  "ekRandevu": True,
  "randevuZamaniList": []
})
headers = {
  'Accept': 'application/json, text/plain, */*',
  'Accept-Language': 'tr-TR',
  'Access-Control-Allow-Credentials': 'true',
  'Access-Control-Allow-Headers': 'Authorization,Content-Type, Accept, X-Requested-With, remember-me',
  'Access-Control-Allow-Methods': 'DELETE, POST, GET, OPTIONS',
  'Access-Control-Allow-Origin': '*',
  'Access-Control-Max-Age': '3600',
  'Authorization': 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJkODc2Yjk1NC0xMDBkLTQ0NjYtYWQyZS1kMzUxM2MwNDk0MzQiLCJpYXQiOjE3MTEyMjU3MzUsImV4cCI6MTcxMTI5NzczNSwidXNlciI6eyJ1dWlkIjoiYjU4MDEyNTQtZGQ0YS00MTQzLWI4ZWQtZDRjMTIzZTM3ODQzIiwidG9rZW5UaXBpIjoiVkFUQU5EQVMiLCJpc2xlbUthbmFsaSI6IlZBVEFOREFTX0VERVZMRVQifX0.I1OdATnYpjesDcd9Tcy7Cv98EZZ1srd_5vz-XwYjIh70o-CDEwroj642B5Rnrc2Yi_yd3qVH1cCl42QR_pQHAQ',
  'Connection': 'keep-alive',
  'Content-Type': 'application/json',
  'Origin': 'https://mhrs.gov.tr',
  'Referer': 'https://mhrs.gov.tr/',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-site',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0',
  'sec-ch-ua': '"Not A(Brand";v="99", "Opera GX";v="107", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"lang":"tr-TR","success":true,"infos":[{"kodu":"RND4000","mesaj":"Aradığınız kriterlerde uygun randevular bulunmaktadır. (RND4000)"}],"warnings":[],"errors":[],"data":{"hastane":[{"hekim":{"id":"75c29b2f-6e7d-4c92-9285-77d2caf9490b","mhrsHekimId":162665,"ad":"FERİDE DİLEK","soyad":"ASLANHAN","cinsiyet":{"val":"K","valText":"Kadın"}},"muayeneYeri":{"id":7349872,"adi":"PSİKİYATRİ 1 TAKSİM (Taksim Ana Binası)"},"kurum":{"mhrsKurumId":682803,"mhrsAnaKurumId":0,"kurumAdi":"İSTANBUL- (AVRUPA)-TAKSİM EĞİTİM VE ARAŞTIRMA HASTANESİ","kurumKisaAdi":"TAKSİM EĞİTİM VE ARAŞTIRMA HASTANESİ","kurumTurId":27,"ilIlce":{"mhrsIlId":341,"dkIlKodu":341,"ilAdi":"İSTANBUL(AVRUPA)","mhrsIlceId":1186,"dkIlceKodu":1186,"ilceAdi":"BEYOĞLU"}},"kurumBilgileri":{"mhrsKurumId":682803,"halkDilindekiAdi":"TAKSİM İLK YARDIM HASTANESİ","telefonNumarasi":2129095000,"eposta":"taksimeah.yonetim@saglik.gov.tr","adres":"TAKSİM ANA BİNA : KATİP ÇELEBİ MAH. SIRASELVİLER CAD. NO:48 BEYOĞLU  / İSTANBUL\n","enlem":41.032955448
# ...

# %%
import json
json_data=json.loads(response.text)
hastanes=json_data["data"]["hastane"]
hastane=hastanes[1]
for hastane in hastanes:
    print(hastane["hekim"]["ad"],hastane["hekim"]["soyad"])
# Out:
# FERİDE DİLEK ASLANHAN
# ELİF ÜSTÜNER
# AYHAN ERGİN
# ALİ GÖRKEM GENÇER
# MEHTAP ARSLAN
# BAHAR EKEN
# BEGÜM OĞUR
# ÖZGÜR MADEN
# MELİHA ZENGİN EROĞLU

# %%
Mihriban Dalkıran
Bahri İnce
Fatma Çölkesen
Gülhan Karaer
Ersel Bulu
Aynur Görmez
Bilge Evren
Emre Şahin
İbrahim Akbaş

# %%
import requests
import json

url = "https://prd.mhrs.gov.tr/api/kurum-rss/randevu/slot-sorgulama/slot"

payload = json.dumps({
  "aksiyonId": 200,
  "mhrsHekimId": 162665,
  "mhrsIlId": 34,
  "mhrsKlinikId": 181,
  "mhrsKurumId": 682803,
  "muayeneYeriId": -1,
  "cinsiyet": "F",
  "tumRandevular": False,
  "ekRandevu": True,
  "randevuZamaniList": []
})
headers = {
  'Accept': 'application/json, text/plain, */*',
  'Accept-Language': 'tr-TR',
  'Access-Control-Allow-Credentials': 'true',
  'Access-Control-Allow-Headers': 'Authorization,Content-Type, Accept, X-Requested-With, remember-me',
  'Access-Control-Allow-Methods': 'DELETE, POST, GET, OPTIONS',
  'Access-Control-Allow-Origin': '*',
  'Access-Control-Max-Age': '3600',
  'Authorization': 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJkODc2Yjk1NC0xMDBkLTQ0NjYtYWQyZS1kMzUxM2MwNDk0MzQiLCJpYXQiOjE3MTEyMjU3MzUsImV4cCI6MTcxMTI5NzczNSwidXNlciI6eyJ1dWlkIjoiYjU4MDEyNTQtZGQ0YS00MTQzLWI4ZWQtZDRjMTIzZTM3ODQzIiwidG9rZW5UaXBpIjoiVkFUQU5EQVMiLCJpc2xlbUthbmFsaSI6IlZBVEFOREFTX0VERVZMRVQifX0.I1OdATnYpjesDcd9Tcy7Cv98EZZ1srd_5vz-XwYjIh70o-CDEwroj642B5Rnrc2Yi_yd3qVH1cCl42QR_pQHAQ',
  'Connection': 'keep-alive',
  'Content-Type': 'application/json',
  'Origin': 'https://mhrs.gov.tr',
  'Referer': 'https://mhrs.gov.tr/',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-site',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0',
  'sec-ch-ua': '"Not A(Brand";v="99", "Opera GX";v="107", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"lang":"tr-TR","success":true,"infos":[{"kodu":"RND4000","mesaj":"Aradığınız kriterlerde uygun randevular bulunmaktadır. (RND4000)"}],"warnings":[],"errors":[],"data":[{"hekimSlotList":[{"muayeneYeriSlotList":[{"saatSlotList":[{"slotList":[{"id":1535842922,"fkCetvelId":2374042516,"baslangicZamani":"2024-04-05 08:30:00","bitisZamani":"2024-04-05 08:45:00","cetvelIsKurallari":{"id":78840866,"cetvel":null,"enBuyukYas":null,"enKucukYas":"P18Y","cinsiyet":null,"cetvelOzellikModel":null},"slot":{"id":1535842922,"fkCetvelId":2374042516,"mhrsKurumId":682803,"mhrsKlinikId":181,"mhrsHekimId":162665,"muayeneYeriId":7349872,"fkAksiyonId":200,"slotHastaSayisi":2,"randevuSuresi":15,"kullanim":2,"kalanKullanim":0,"baslangicZamani":"2024-04-05 08:30:00","bitisZamani":"2024-04-05 08:45:00","kayitZamani":null,"aksiyonAdi":"Muayene"},"bos":false,"isKurali":false,"kapasite":2,"bosKapasite":18,"ek":false,"uygunRandevuGecmisSlot":false,"rezerveTuruData":null,"uzaktanDegerlendirmeVarmi":false,"baslangicZa
# ...

# %%
json2=json.loads(response.text)
saatSlots=json2["data"][0]["hekimSlotList"][0]["muayeneYeriSlotList"][0]["saatSlotList"]
saatSlot=json2["data"][0]["hekimSlotList"][0]["muayeneYeriSlotList"][0]["saatSlotList"][0]
saatSlot
# Out:
# {'slotList': [{'id': 1535842922,
#    'fkCetvelId': 2374042516,
#    'baslangicZamani': '2024-04-05 08:30:00',
#    'bitisZamani': '2024-04-05 08:45:00',
#    'cetvelIsKurallari': {'id': 78840866,
#     'cetvel': None,
#     'enBuyukYas': None,
#     'enKucukYas': 'P18Y',
#     'cinsiyet': None,
#     'cetvelOzellikModel': None},
#    'slot': {'id': 1535842922,
#     'fkCetvelId': 2374042516,
#     'mhrsKurumId': 682803,
#     'mhrsKlinikId': 181,
#     'mhrsHekimId': 162665,
#     'muayeneYeriId': 7349872,
#     'fkAksiyonId': 200,
#     'slotHastaSayisi': 2,
#     'randevuSuresi': 15,
#     'kullanim': 2,
#     'kalanKullanim': 0,
#     'baslangicZamani': '2024-04-05 08:30:00',
#     'bitisZamani': '2024-04-05 08:45:00',
#     'kayitZamani': None,
#     'aksiyonAdi': 'Muayene'},
#    'bos': False,
#    'isKurali': False,
#    'kapasite': 2,
#    'bosKapasite': 18,
#    'ek': False,
#    'uygunRandevuGecmisSlot': False,
#    'rezerveTuruData': None,
# ...
