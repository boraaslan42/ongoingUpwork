f743bff0249c26fc04d050575e6b920f045c:HzLb0ETsfJwhGIcNHQhd3l2NkJAOE2Jqn2O6nVs1bVseVx2UsCzCRfUIqB8G6zM6slzZbRlP7RzxxbdRn0jnoA==:1000:XoNExeCUAB5Hn7x6Ab4V/rwSXB/NMPC2uRDP6rgyEzMc1PltF3bnlQ77mYdfgDNMA0huKC2VzAxEx8tpvjFm7814sgjCfHcfvfmyosiyKT8tmvPFsoijgbUQA/zRB29mGGE9sd3KUP0XYA351649cMJbqyfFuBUbh4EFC+Me4HTfvb/c6fDpwEUwN5TLAIyqG6p0ubKsZHIFjR4PcEmbDi3hzwP4O1fjLI9dHSGEZL8=; search=6|1712248925157%7Crect%3D34.17614808572149%2C-84.17773904296877%2C33.37137970868935%2C-84.71057595703127%26rid%3D37211%26disp%3Dmap%26mdm%3Dauto%26p%3D2%26z%3D1%26listPriceActive%3D1%26fs%3D1%26fr%3D0%26mmm%3D0%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%26featuredMultiFamilyBuilding%3D0%26student-housing%3D0%26income-restricted-housing%3D0%26military-housing%3D0%26disabled-housing%3D0%26senior-housing%3D0%26commuteMode%3Ddriving%26commuteTimeOfDay%3Dnow%09%0937211%09%7B%22isList%22%3Atrue%2C%22isMap%22%3Afalse%7D%09%09%09%09%09; _clsk=1qmwqaq%7C1709656927763%7C22%7C0%7Ct.clarity.ms%2Fcollect; _gat=1; x-amz-continuous-deployment-state=%2F%2F%2F%2F%2FAAAAAQAAAAAAAAAAAAAAAQAAAAzmCFftCpGn4H%2F5Ji91HYJfBq4ZTT2MPXT0YGzR; search=6|1711988831769%7Crect%3D33.930481%2C-84.216722%2C33.618653%2C-84.671593%26rid%3D37211%26disp%3Dmap%26mdm%3Dauto%26p%3D2%26z%3D1%26listPriceActive%3D1%26fs%3D1%26fr%3D0%26mmm%3D0%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%26featuredMultiFamilyBuilding%3D0%26student-housing%3D0%26income-restricted-housing%3D0%26military-housing%3D0%26disabled-housing%3D0%26senior-housing%3D0%26commuteMode%3Ddriving%26commuteTimeOfDay%3Dnow%09%0937211%09%7B%22isList%22%3Atrue%2C%22isMap%22%3Afalse%7D%09%09%09%09%09',
  'referer': 'https://www.zillow.com/homedetails/1261-Lavista-Rd-NE-APT-J3-Atlanta-GA-30324/2083592326_zpid/',
  'sec-ch-ua': '"Not A(Brand";v="99", "Opera GX";v="107", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 OPR/107.0.0.0'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"data":{"property":{"listingDataSource":"Phoenix","zpid":2083592326,"city":"Atlanta","state":"GA","homeStatus":"FOR_SALE","address":{"streetAddress":"1261 Lavista Rd NE APT J3","city":"Atlanta","state":"GA","zipcode":"30324","neighborhood":null,"community":null,"subdivision":null},"isListingClaimedByCurrentSignedInUser":false,"isCurrentSignedInAgentResponsible":false,"bedrooms":2,"bathrooms":2,"price":175000,"yearBuilt":1964,"streetAddress":"1261 Lavista Rd NE APT J3","zipcode":"30324","isCurrentSignedInUserVerifiedOwner":false,"regionString":"Atlanta GA 30324","propertyUpdatePageLink":null,"moveHomeMapLocationLink":null,"propertyEventLogLink":null,"editPropertyHistorylink":null,"collections":{"modules":[{"name":"Similar homes","placement":"NEIGHBORHOOD","propertyDetails":[{"miniCardPhotos":[{"url":"https://photos.zillowstatic.com/fp/d72d0375580412aa71b610ff686269d4-p_c.jpg"}],"price":249000,"currency":"USD","bedrooms":2,"bathrooms":2,"livingArea":1250,"livingAreaValue":1250,"living
# ...

# %%
json_data = json.loads(response.text)
homeForYou=json_data["data"]["property"]["collections"]["modules"][0]["propertyDetails"]
home=homeForYou[1]
json_data=json_data["data"]["property"]
Similar_homes=json_data["collections"]["modules"][0]["propertyDetails"]
Homesfor_you=json_data["collections"]["modules"][1]["propertyDetails"]
allHouses=Similar_homes+Homesfor_you
for house in allHouses:
    print(house["zpid"])
# Out:
# 2087831141
# 343424453
# 2053075690
# 35864484
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       7 allHouses=Similar_homes+Homesfor_you
#       8 for house in allHouses:
# ----> 9     print(house["zpid"])
#
# TypeError: 'NoneType' object is not subscriptable
