# %%
import requests
import json
import pandas as pd
# both functions use the same payload header dictionary
# payload & headers must be picked from api request in network tab of wanted zillow search with chosen filters

payload = json.dumps({
  "searchQueryState": {
    "pagination": {
      "currentPage": 2
    },
    "isMapVisible": False,
    "mapBounds": {
      "west": -79.76259,
      "east": -71.777491,
      "south": 40.477399,
      "north": 45.015865
    },
    "usersSearchTerm": "NY",
    "regionSelection": [
      {
        "regionId": 43,
        "regionType": 2
      }
    ],
    "filterState": {
      "sortSelection": {
        "value": "days"
      },
      "isForSaleByAgent": {
        "value": False
      },
      "isForSaleByOwner": {
        "value": False
      },
      "isNewConstruction": {
        "value": False
      },
      "isComingSoon": {
        "value": False
      },
      "isAuction": {
        "value": False
      },
      "isForSaleForeclosure": {
        "value": False
      },
      "isRecentlySold": {
        "value": True
      },
      "isAllHomes": {
        "value": True
      }
    },
    "isListVisible": True
  },
  "wants": {
    "cat1": [
      "listResults"
    ]
  },
  "requestId": 2,
  "isDebugRequest": False
})
headers = {
    "authority": "www.zillow.com",
    "accept": "*/*",
    "accept-language": "tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7",
    "content-type": "application/json",
    "cookie": 'zguid=24|%24abac79bb-72ad-4d9e-9dde-b1751e59deae; _ga=GA1.2.680147625.1692801387; zjs_anonymous_id=%22abac79bb-72ad-4d9e-9dde-b1751e59deae%22; zjs_user_id=null; zg_anonymous_id=%22a2ea7840-c28b-4f1b-8a00-69913b909e63%22; _hp2_id.1215457233=%7B%22userId%22%3A%222522749834967336%22%2C%22pageviewId%22%3A%226913396349729521%22%2C%22sessionId%22%3A%22503083603946677%22%2C%22identity%22%3Anull%2C%22trackerVersion%22%3A%224.0%22%7D; __pdst=c1df509b570446c28d6bf779e3e32721; _pxvid=729a779c-41c2-11ee-a58d-0dbd2da9169f; _pin_unauth=dWlkPU56azFOalJqWVRBdE5tUmtNaTAwWldZd0xXRXhOVEV0TjJRM01HWTJNbVUxTkdJeQ; JSESSIONID=D50653869FEDC01AC352F4F8369937DF; zgsession=1|ec6c4446-4ae0-4492-98df-e3b878930d6f; _gid=GA1.2.1968072043.1706285815; AWSALB=xRKyk0l88mL8RY57Yel+w3B/nab1GWQNxoht/Mu2hxABpTULFbnTG3SAsw+oma1ba/yjo2+mvN/f96CESJFJM7uP5WDeuOKAkI6KgJ/O0pAWu7PEUfVWN4GArDD5; AWSALBCORS=xRKyk0l88mL8RY57Yel+w3B/nab1GWQNxoht/Mu2hxABpTULFbnTG3SAsw+oma1ba/yjo2+mvN/f96CESJFJM7uP5WDeuOKAkI6KgJ/O0pAWu7PEUfVWN4GArDD5; g_state={"i_p":1706372217990,"i_l":2}; _gcl_au=1.1.217113811.1706285818; DoubleClickSession=true; _uetsid=54e2c690bc6611ee80e08bb598d45fbc; _uetvid=736f3ff041c211ee80bd31235bff95e5; _clck=1a2goaf%7C2%7Cfiq%7C0%7C1330; _gat=1; search=6|1708877940455%7Crect%3D44.28919455063632%2C-106.45264509375001%2C29.855816427991694%2C-132.16065290625%26rid%3D9%26disp%3Dmap%26mdm%3Dauto%26p%3D1%26z%3D1%26listPriceActive%3D1%26price%3D2500000-%26mp%3D12488-%26fs%3D1%26fr%3D0%26mmm%3D0%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%26featuredMultiFamilyBuilding%3D0%26student-housing%3D0%26income-restricted-housing%3D0%26military-housing%3D0%26disabled-housing%3D0%26senior-housing%3D0%26commuteMode%3Ddriving%26commuteTimeOfDay%3Dnow%09%099%09%7B%22isList%22%3Atrue%2C%22isMap%22%3Afalse%7D%09%09%09%09%09; _clsk=s4ie5e%7C1706285940967%7C8%7C0%7Cu.clarity.ms%2Fcollect; search=6|1708878079065%7Crect%3D44.28919455063632%2C-106.45264509375001%2C29.855816427991694%2C-132.16065290625%26rid%3D9%26disp%3Dmap%26mdm%3Dauto%26p%3D2%26z%3D1%26listPriceActive%3D1%26price%3D2500000-%26mp%3D12488-%26fs%3D1%26fr%3D0%26mmm%3D0%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%26featuredMultiFamilyBuilding%3D0%26student-housing%3D0%26income-restricted-housing%3D0%26military-housing%3D0%26disabled-housing%3D0%26senior-housing%3D0%26commuteMode%3Ddriving%26commuteTimeOfDay%3Dnow%09%099%09%7B%22isList%22%3Atrue%2C%22isMap%22%3Afalse%7D%09%09%09%09%09; x-amz-continuous-deployment-state=AYABeA+m5kqw1F2aYT7PqxaVvGsAPgACAAFEAB1kM2Jsa2Q0azB3azlvai5jbG91ZGZyb250Lm5ldAABRwAVRzA3MjU1NjcyMVRZRFY4RDcyVlpWAAEAAkNEABpDb29raWUAAACAAAAADFT6ITIB595nsyjWgAAwJ8Gb9978%2FXPm59tRlUQuYcNI3OEGGKWI+NuXrBhEgj3xfrb4XMoW37XSx0Fu79FGAgAAAAAMAAQAAAAAAAAAAAAAAAAAAJ2PhuYpbN2WZs9Kcsl0pez%2F%2F%2F%2F%2FAAAAAQAAAAAAAAAAAAAAAQAAAAwyMKdAzfZUh%2F+Vml+zi6CWm5YE84qyzaP4MfID',
    "origin": "https://www.zillow.com",
    "referer": "https://www.zillow.com/ca/?searchQueryState=%7B%22isMapVisible%22%3Afalse%2C%22mapBounds%22%3A%7B%22north%22%3A44.28919455063632%2C%22south%22%3A29.855816427991694%2C%22east%22%3A-106.45264509375001%2C%22west%22%3A-132.16065290625%7D%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22price%22%3A%7B%22min%22%3A2500000%7D%2C%22mp%22%3A%7B%22min%22%3A12488%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A6%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A9%2C%22regionType%22%3A2%7D%5D%2C%22pagination%22%3A%7B%7D%7D",
    "sec-ch-ua": '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
}

# function gets total page number for the specific search
def getTotalPageNumber(payload=payload, headers=headers):
    url = "https://www.zillow.com/async-create-search-page-state"
    response = requests.request("PUT", url, headers=headers, data=payload)
    json_data = json.loads(response.text)
    return json_data["cat1"]["searchList"]["totalPages"]

totalPageNumber = getTotalPageNumber()



# process integer prices like 1234567 to 1,234,567
def processCommas(integer):
    word = str(integer)
    for i in range(len(word) - 3, 0, -3):
        word = word[:i] + "," + word[i:]
    return word

# this function calls the api with the pagination
# returns the json data which has each listings first layer data in it.

def getHousesPerPage(pagination, payload=payload, headers=headers):
    url = "https://www.zillow.com/async-create-search-page-state"
    json_data = json.loads(payload)
    json_data["searchQueryState"]["pagination"]["currentPage"] = pagination
    payload = json.dumps(json_data)
    response = requests.request("PUT", url, headers=headers, data=payload)
    json_data = json.loads(response.text)
    return json_data["cat1"]["searchResults"]["listResults"]

#List that is going to hold dicts of each house and will be fed to excel
excelList = []

for i in range(1, totalPageNumber + 1):
    print("Scraping page:", i, "/", totalPageNumber)    
    houseList = getHousesPerPage(i)
    for house in houseList:
        data = {}
        testWords = [
            "detailUrl",
            "price",
            "address",
            "marketingStatusSimplifiedCd",
            "address",
            "addressZipcode",
            "beds",
            "baths",
            "area",
        ]
        DictWords = [
            "Listing Url",
            "Price",
            "Address",
            "Marketing Status",
            "Address",
            "Address Zipcode",
            "Beds",
            "Baths",
            "Sqft Area",
        ]
        for dictWord, testWord in zip(DictWords, testWords):
            try:
                if dictWord == "Baths":
                    data[dictWord] = int(house[testWord])

                else:
                    data[dictWord] = house[testWord]
            except:
                data[dictWord] = "NA"
        testWords2 = ["homeType", "zestimate", "rentZestimate", "daysOnZillow"]
        dictWords2 = ["Home Type", "Zestimate", "Rent Zestimate", "Days On Zillow"]
        for dictWord, testWord in zip(dictWords2, testWords2):
            try:
                if testWord == "zestimate" or testWord == "rentZestimate":

                    data[dictWord] = "$" + processCommas(
                        house["hdpData"]["homeInfo"][testWord]
                    )

                else:
                    data[dictWord] = house["hdpData"]["homeInfo"][testWord]
            except:
                data[dictWord] = "NA"
        try:
            data["carouselPhotos"] = house["carouselPhotos"]
        except:
            data["carouselPhotos"] = "NA"
        excelList.append(data)
# Out:
# Scraping page 1 / 20
# Scraping page 2 / 20
# Scraping page 3 / 20
# Scraping page 4 / 20
# Scraping page 5 / 20
# Scraping page 6 / 20
# Scraping page 7 / 20
# Scraping page 8 / 20
# Scraping page 9 / 20
# Scraping page 10 / 20
# Scraping page 11 / 20
# Scraping page 12 / 20
# Scraping page 13 / 20
# Scraping page 14 / 20
# Scraping page 15 / 20
# Scraping page 16 / 20
# Scraping page 17 / 20
# Scraping page 18 / 20
# Scraping page 19 / 20
# Scraping page 20 / 20

# %%
sict={'zpid': '35943376', 'id': '35943376', 'rawHomeStatusCd': 'ForSale', 'marketingStatusSimplifiedCd': 'For Sale by Agent', 'imgSrc': 'https://photos.zillowstatic.com/fp/024ec7a214e8a7156489e57a2b8b8dda-p_e.jpg', 'hasImage': True, 'detailUrl': 'https://www.zillow.com/homedetails/143-W-Paces-Ferry-Rd-NW-Atlanta-GA-30305/35943376_zpid/', 'statusType': 'FOR_SALE', 'statusText': 'House for sale', 'countryCurrency': '$', 'price': '$2,995,000', 'unformattedPrice': 2995000, 'address': '143 W Paces Ferry Rd NW, Atlanta, GA 30305', 'addressStreet': '143 W Paces Ferry Rd NW', 'addressCity': 'Atlanta', 'addressState': 'GA', 'addressZipcode': '30305', 'isUndisclosedAddress': False, 'beds': 6, 'baths': 7.0, 'area': 8200, 'latLong': {'latitude': 33.8438, 'longitude': -84.38683}, 'isZillowOwned': False, 'variableData': {'type': 'DAYS_ON', 'text': '6 days on Zillow'}, 'hdpData': {'homeInfo': {'zpid': 35943376, 'streetAddress': '143 W Paces Ferry Rd NW', 'zipcode': '30305', 'city': 'Atlanta', 'state': 'GA', 'latitude': 33.8438, 'longitude': -84.38683, 'price': 2995000.0, 'bathrooms': 7.0, 'bedrooms': 6.0, 'livingArea': 8200.0, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'FOR_SALE', 'daysOnZillow': 6, 'isFeatured': False, 'shouldHighlight': False, 'rentZestimate': 15249, 'listing_sub_type': {'is_FSBA': True}, 'isUnmappable': False, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'FOR_SALE', 'priceForHDP': 2995000.0, 'timeOnZillow': 545693000, 'isNonOwnerOccupied': True, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 2085700.0, 'lotAreaValue': 0.7021999999999999, 'lotAreaUnit': 'acres', 'isShowcaseListing': False}}, 'isSaved': False, 'isUserClaimingOwner': False, 'isUserConfirmedClaim': False, 'pgapt': 'ForSale', 'sgapt': 'For Sale (Broker)', 'shouldShowZestimateAsPrice': False, 'has3DModel': False, 'hasVideo': False, 'isHomeRec': False, 'hasAdditionalAttributions': True, 'isFeaturedListing': False, 'isShowcaseListing': False, 'list': True, 'relaxed': False, 'info1String': 'MLS ID #7341004', 'info3String': 'https://photos.zillowstatic.com/fp/d2c28114f36af4dea165c93003b4cd2e-zillow_web_48_23.jpg', 'brokerName': "Ansley Real Estate | Christie's International Real Estate", 'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/024ec7a214e8a7156489e57a2b8b8dda-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/d8eb830d566f98f2de8f0791beb61965-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/489553ce26e6410c591dafa44990c940-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/946eeac42704ba22f66b45e90ec0ed6e-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/aab8ce5f9c29bc7f49e7d06ab89a2ce2-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/0f3584473b9161de0784407f9defc2ec-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/6e1e27841be5987b0912f727f8adb371-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/0dae7e187dd664a2e3956632e96c25f9-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/b5ee8584155008f774d0229582d22baa-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/51b3069e2f8a7caded506cc86ccc5d33-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/860e4c88089c1e531a42275d4bdc21c4-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/625652ce67a0a6cd7480386248643766-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/806e780dd02d0e907e58929be64934d3-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/3440b935d1fef95fb93c10518739081b-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/e5ca907d28bddee0182e8bd06f0a7515-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/ddd120c4c15b02801d0f9bcaab5f4498-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/a28f67e33befb391a9948c6857e105bb-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/3e244746fe5938233113a8b0efb8f7e4-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/77f7ef1a3a71d2892b53358316b858f5-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/aba1749c4954ab40e237e1e3fec23b77-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/2ebc233af942d4375e3a0289b0eeb3be-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/90406f33a9d31c92db87a96afe8481cd-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/659a3d19826f217e82eee610da88f8c3-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/51c0630cddc46b7318be0e0b14bdd8cc-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/09b890c1a21b9507250b222fb9b587b6-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/60e66c704b539209f92511eb45aed44f-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/d2376ea360ed9cd951086f939ab7d0b1-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/8a24b51b8ad73e8dcd11c66e0748884f-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/e580db61da92686fef1002ccaadbc3f4-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/8ce38d2ab98537b71d6fd29339f59dfb-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/fde6b2db1432f256e301c01f792f817b-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/51180652c865bcff0ec8d4e9a15e1bda-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/e7e1f6c0893a01f18d915226c553b41c-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/e73c0713d80996883382d0c86cb8e3f1-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/01081a1c2b43275ef35510b9049ae149-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/5b93a44e6288fbdced2415bac7490cd8-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/ec5bc2657c0d45b44f455adde0d02252-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/9395bf2540cdc7e8d9eb3456ab498c01-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/35dd3bc8a1aa906af3fe47cabc62df05-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/d6d8e932ae6a55df3eb76ee3f240b2fa-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/fbecbe56e66605d5b7e3ec15514f2d7a-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/746e5ad4895cf04b1a8903be39674fcc-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/85a82d2cb2f46374bde8b7303ba27899-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/bff1e2f35da2ae102ff9e74a826f3344-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/f7270077662ebc53ba699d5f491d2d3e-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/09b6ce12aca8ae93bb32ac577f4ba181-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/afdc74207f86d5a23f3834daa1a8ea9c-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/3b48d9353d691773ba80348ecc485f5c-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/3258204f11bebd1326fc483f9ef4b8dd-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/7c5ef5be50be56877256bdad10106c8e-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/6c2ded7b1c208116a5d6412889be1802-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/e686b10cbc606e1e2a8457cdd16eb231-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/cf1a07c1f783b9f85c3b1c2a17b4826c-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/5e6243b0e57924868fdd4ba968009006-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/f3e1d848dce352d0bcdba8b6781d6f79-p_e.jpg'}, {'url': 'https://photos.zillowstatic.com/fp/7a1a33826b1e748e77909caea8e0ec4f-p_e.jpg'}]}
for sic in sict:
    print(sic,end=", ")
print("\n")
# Out:
# zpid, id, rawHomeStatusCd, marketingStatusSimplifiedCd, imgSrc, hasImage, detailUrl, statusType, statusText, countryCurrency, price, unformattedPrice, address, addressStreet, addressCity, addressState, addressZipcode, isUndisclosedAddress, beds, baths, area, latLong, isZillowOwned, variableData, hdpData, isSaved, isUserClaimingOwner, isUserConfirmedClaim, pgapt, sgapt, shouldShowZestimateAsPrice, has3DModel, hasVideo, isHomeRec, hasAdditionalAttributions, isFeaturedListing, isShowcaseListing, list, relaxed, info1String, info3String, brokerName, carouselPhotos,

# %%
# given data MUST be a LIST that has DICTS with same key names as ELEMENTS

#appends data to xlsx file, does not deletes the existing data

#creates a new file if the file does not exist in cd

def append_toXlsx(dictionaryList, fileName):
    try:
        df_existing = pd.read_excel(fileName)
        print(fileName + " exists")
    except:
        print("File does not exist creating file: " + fileName)
        df_existing = None
    df_new = pd.DataFrame(dictionaryList)
    df_combined = pd.concat([df_existing, df_new], ignore_index=True)
    with pd.ExcelWriter(fileName, engine="openpyxl") as writer:
        df_combined.to_excel(writer, index=False, sheet_name="Sheet")
    print("Data is appended to", fileName)


append_toXlsx(excelList, "test.xlsx")
# Out:
# File does not exist creating file: test.xlsx
# Data is added to test.xlsx
