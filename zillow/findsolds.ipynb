# %%
#scrappedUrl
#https://www.zillow.com/boca-raton-fl/sold/?searchQueryState=%7B"pagination"%3A%7B%7D%2C"isMapVisible"%3Atrue%2C"mapBounds"%3A%7B"west"%3A-80.30778961206055%2C"east"%3A-80.05544738793945%2C"south"%3A26.273208419488576%2C"north"%3A26.478980540955195%7D%2C"usersSearchTerm"%3A"Boca%20Raton%2C%20FL"%2C"regionSelection"%3A%5B%7B"regionId"%3A10477%2C"regionType"%3A6%7D%5D%2C"filterState"%3A%7B"sort"%3A%7B"value"%3A"days"%7D%2C"ah"%3A%7B"value"%3Atrue%7D%2C"rs"%3A%7B"value"%3Atrue%7D%2C"fsba"%3A%7B"value"%3Afalse%7D%2C"fsbo"%3A%7B"value"%3Afalse%7D%2C"nc"%3A%7B"value"%3Afalse%7D%2C"cmsn"%3A%7B"value"%3Afalse%7D%2C"auc"%3A%7B"value"%3Afalse%7D%2C"fore"%3A%7B"value"%3Afalse%7D%7D%2C"isListVisible"%3Atrue%2C"mapZoom"%3A12%7D

# %%
import requests
import json

url = "https://www.zillow.com/async-create-search-page-state"

payload = json.dumps({
  "searchQueryState": {
    "pagination": {"currentPage":22},
    "isMapVisible": True,
    "mapBounds": {
      "west": -80.30778961206055,
      "east": -80.05544738793945,
      "south": 26.273208419488576,
      "north": 26.478980540955195
    },
    "usersSearchTerm": "Boca Raton, FL",
    "regionSelection": [
      {
        "regionId": 10477,
        "regionType": 6
      }
    ],
    "filterState": {
      "sortSelection": {
        "value": "days"
      },
      "isAllHomes": {
        "value": True
      },
      "isRecentlySold": {
        "value": True
      },
      "isForSaleByAgent": {
        "value": False
      },
      "isForSaleByOwner": {
        "value": False
      },
      "isNewConstruction": {
        "value": False
      },
      "isComingSoon": {
        "value": False
      },
      "isAuction": {
        "value": False
      },
      "isForSaleForeclosure": {
        "value": False
      }
    },
    "isListVisible": True,
    "mapZoom": 12
  },
  "wants": {
    "cat1": [
      "listResults",
      "mapResults"
    ]
  },
  "requestId": 3,
  "isDebugRequest": False
})
headers = {
  'authority': 'www.zillow.com',
  'accept': '*/*',
  'accept-language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
  'content-type': 'application/json',
  'cookie': 'zguid=24|%243882675e-a8cf-47fa-901e-a17fc4ad28a5; _ga=GA1.2.503817444.1704390763; zjs_anonymous_id=%223882675e-a8cf-47fa-901e-a17fc4ad28a5%22; zjs_user_id=null; zg_anonymous_id=%22266cdf20-1bf3-438b-b745-ed951cd5ef03%22; _gcl_au=1.1.222472829.1704390767; __pdst=44b14fd34b3442408f84fa5ee1a6a6b7; _pin_unauth=dWlkPU1UaGxOVEl5TmpFdE1UQmxZeTAwTW1abExUazNNMlV0TlRjMllXWm1ZamN6WW1Saw; g_state={"i_p":1704397979067,"i_l":1}; _pxvid=1dc8adab-ab2a-11ee-9083-220b0e6544cf; _cs_c=0; _cs_id=e62cb76b-12ba-a85b-d859-2298dfa2e680.1706464967.1.1706466205.1706464967.1.1740628967883.1; zgsession=1|17dfc841-cf16-4535-98e7-ce1ea6647c23; pxcts=8e67a416-d609-11ee-a28b-4144f7c0d32d; DoubleClickSession=true; _hp2_id.1215457233=%7B%22userId%22%3A%224884671301086620%22%2C%22pageviewId%22%3A%223199683513061121%22%2C%22sessionId%22%3A%226903122911978002%22%2C%22identity%22%3Anull%2C%22trackerVersion%22%3A%224.0%22%7D
url, headers=headers, data=payload)

print(response.text)
# Out:
# {"user":{"isLoggedIn":false,"hasHousingConnectorPermission":false,"savedHomesCount":0,"personalizedSearchTraceID":"c365611d68e9de639b7345d1cfa2510e","guid":"3882675e-a8cf-47fa-901e-a17fc4ad28a5","zuid":"","isBot":false,"email":"","displayName":""},"mapState":{"customRegionPolygonWkt":null,"schoolPolygonWkt":null,"isCurrentLocationSearch":false,"userPosition":{"lat":null,"lon":null}},"regionState":{"regionInfo":[{"regionId":10477,"regionType":6,"regionName":"Boca Raton","displayName":"Boca Raton FL","isPointRegion":false}],"regionBounds":{"north":26.431541,"south":26.320713,"east":-80.065566,"west":-80.297671}},"searchPageSeoObject":{"baseUrl":"/boca-raton-fl/sold/22_p/","windowTitle":"Recently Sold Homes in Boca Raton FL - 21223 Transactions | Zillow","metaDescription":"Browse data on the 21223 recent real estate transactions in Boca Raton FL. Great for discovering comps, sales history, photos, and more."},"requestId":3,"cat1":{"searchResults":{"listResults":[{"zpid":"67180200","id":
# ...

# %%
json_data = json.loads(response.text)
print(json_data["cat1"]["searchList"])
json_data["cat1"]["searchResults"]

#46711168
# Out:
# {'expansionDistance': 0, 'staticBaseUrl': None, 'zeroResultsFilters': None, 'pagination': {'previousUrl': '/boca-raton-fl/sold/21_p/'}, 'adsConfig': {'navAdSlot': 'zillow/search_results_1/buy_sold/search_1', 'displayAdSlot': 'zillow/search_results_1/buy_sold/b_right_p1', 'targets': {'guid': '3882675e-a8cf-47fa-901e-a17fc4ad28a5', 'vers': 'constellation_dynamic,srp_ad_target_refactor', 'premieragent': 'no', 'state': 'FL', 'dma': '55', 'cnty': 'Palm_Beach', 'city': 'Boca_Raton', 'mlat': '26.376094480221887', 'mlong': '-80.1816185', 'listtp': 'buy_sold', 'searchtp': 'city'}, 'needsUpdate': True}, 'totalResultCount': 21223, 'resultsPerPage': 41, 'totalPages': 20, 'limitSearchResultsCount': None, 'listResultsTitle': 'Boca Raton FL Recently Sold Homes', 'resultContexts': [{'ssid': 60, 'context': "All listings featuring the BMLS logo are provided by Beaches MLS, Inc. This information is not verified for authenticity or accuracy and is not guaranteed. Copyright 2024 Beaches Multiple Listing 
# ...

# %%
# both functions use the same payload header dictionary
# payload & headers must be picked from api request in network tab of wanted zillow search with chosen filters


# function gets total page number for the specific search
def getTotalPageNumber(payload=payload, headers=headers):
    url = "https://www.zillow.com/async-create-search-page-state"
    response = requests.request("PUT", url, headers=headers, data=payload)
    json_data = json.loads(response.text)
    return json_data["cat1"]["searchList"]["totalPages"]

totalPageNumber = getTotalPageNumber()



# process integer prices like 1234567 to 1,234,567
def processCommas(integer):
    word = str(integer)
    for i in range(len(word) - 3, 0, -3):
        word = word[:i] + "," + word[i:]
    return word

# this function calls the api with the pagination
# returns the json data which has each listings first layer data in it.

def getHousesPerPage(pagination, payload=payload, headers=headers):
    url = "https://www.zillow.com/async-create-search-page-state"
    json_data = json.loads(payload)
    json_data["searchQueryState"]["pagination"]["currentPage"] = pagination
    payload = json.dumps(json_data)
    response = requests.request("PUT", url, headers=headers, data=payload)
    json_data = json.loads(response.text)
    return json_data["cat1"]["searchResults"]["listResults"]

#List that is going to hold dicts of each house and will be fed to excel
excelList = []

for i in range(1, 35):
    print("Scraping page:", i, "/", totalPageNumber)    
    houseList = getHousesPerPage(i)
    print(len(houseList))
    for house in houseList:
        
        data = {}
        try:
            data["Date Sold"]=house["variableData"]["text"]
        except:
            data["Date Sold"] = "NA"
        testWords = [
            "address",
            "brokerName",
            "detailUrl",
            "imgSrc",
            "price",
            "marketingStatusSimplifiedCd",
            "address",
            "addressZipcode",
            "beds",
            "baths",
            "area",
        ]
        DictWords = [
            "Address",
            "Agent",
            "Listing Url",
            "Main Image Url",
            "Price",
            "Marketing Status",
            "Address",
            "Address Zipcode",
            "Beds",
            "Baths",
            "Sqft Area",
        ]
        for dictWord, testWord in zip(DictWords, testWords):
            try:
                if dictWord == "Baths":
                    data[dictWord] = int(house[testWord])

                else:
                    data[dictWord] = house[testWord]
            except:
                data[dictWord] = "NA"
        testWords2 = ["homeType", "zestimate", "rentZestimate", "daysOnZillow"]
        dictWords2 = ["Home Type", "Zestimate", "Rent Zestimate", "Days On Zillow"]
        for dictWord, testWord in zip(dictWords2, testWords2):
            try:
                if testWord == "zestimate" or testWord == "rentZestimate":

                    data[dictWord] = "$" + processCommas(
                        house["hdpData"]["homeInfo"][testWord]
                    )

                else:
                    data[dictWord] = house["hdpData"]["homeInfo"][testWord]
            except:
                data[dictWord] = "NA"
        try:
            data["Carousel Photos"] = house["carouselPhotos"]
        except:
            data["Carousel Photos"] = "NA"
        excelList.append(data)
# Out:
# Scraping page: 1 / 20
# 41
# Scraping page: 2 / 20
# 41
# Scraping page: 3 / 20
# 41
# Scraping page: 4 / 20
# 41
# Scraping page: 5 / 20
# 41
# Scraping page: 6 / 20
# 41
# Scraping page: 7 / 20
# 41
# Scraping page: 8 / 20
# 41
# Scraping page: 9 / 20
# 41
# Scraping page: 10 / 20
# 41
# Scraping page: 11 / 20
# 41
# Scraping page: 12 / 20
# 41
# Scraping page: 13 / 20
# 41
# Scraping page: 14 / 20
# 41
# Scraping page: 15 / 20
# 41
# Scraping page: 16 / 20
# 41
# Scraping page: 17 / 20
# 41
# Scraping page: 18 / 20
# 41
# Scraping page: 19 / 20
# 41
# Scraping page: 20 / 20
# 41
# Scraping page: 21 / 20
# 41
# Scraping page: 22 / 20
# 41
# Scraping page: 23 / 20
# 41
# Scraping page: 24 / 20
# 41
# Scraping page: 25 / 20
# 0
# Scraping page: 26 / 20
# 0
# Scraping page: 27 / 20
# 0
# Scraping page: 28 / 20
# 0
# Scraping page: 29 / 20
# 0
# Scraping page: 30 / 20
# 0
# Scraping page: 31 / 20
# 0
# Scraping page: 32 / 20
# 0
# Scraping page: 33 / 20
# 0
# Scraping page: 34 / 20
# ...

# %%
# given data MUST be a LIST that has DICTS with same key names as ELEMENTS

#appends data to xlsx file, does not deletes the existing data

#creates a new file if the file does not exist in cd
import pandas as pd
def append_toXlsx(dictionaryList, fileName):
    try:
        df_existing = pd.read_excel(fileName)
        print(fileName + " exists")
    except:
        print("File does not exist creating file: " + fileName)
        df_existing = None
    df_new = pd.DataFrame(dictionaryList)
    df_combined = pd.concat([df_existing, df_new], ignore_index=True)
    with pd.ExcelWriter(fileName, engine="openpyxl") as writer:
        df_combined.to_excel(writer, index=False, sheet_name="Sheet")
    print("Data is appended to", fileName)


append_toXlsx(excelList, "Sold Houses Zillow.xlsx")
# Out:
# File does not exist creating file: Sold Houses Zillow.xlsx
# Data is appended to Sold Houses Zillow.xlsx
